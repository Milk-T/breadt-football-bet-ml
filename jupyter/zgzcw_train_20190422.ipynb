# %%
import pandas as pd
from sklearn import preprocessing

# %% [markdown]
# ## 处理feature表数据

# %%
features_df = pd.read_csv('../data/breadt_football_feature_info_201904221116.csv')

# %%
features_df['v_perf_win'].head()
# Out:
# 0     50% 3
# 1     23% 3
# 2    70% 14
# 3     20% 4
# 4     25% 5
# Name: v_perf_win, dtype: object

# %%
features_df.columns.values
# Out:
# array(['id', 'matchid', 'h_score', 'h_rank', 'h_perf_win', 'h_perf_draw',
#        'h_perf_lose', 'h_host_win', 'h_host_draw', 'h_host_lose',
#        'h_battle_with_front_10_win', 'h_battle_with_front_10_draw',
#        'h_battle_with_front_10_lose', 'h_battle_with_end_10_win',
#        'h_battle_with_end_10_draw', 'h_battle_with_end_10_lose',
#        'h_perf_gs', 'h_perf_gd', 'h_perf_avg_gs', 'h_perf_avg_gd',
#        'h_host_gs', 'h_host_gd', 'h_host_avg_gs', 'h_host_avg_gd',
#        'h_r3_gs', 'h_r3_gd', 'h_r3_avg_gs', 'h_r3_avg_gd',
#        'h_perf_bet_high', 'h_perf_bet_low', 'h_host_bet_high',
#        'h_host_bet_low', 'h_host_0_1_goal', 'h_host_2_3_goal',
#        'h_host_ab_4_goal', 'h_host_0_goal', 'h_host_1_goal',
#        'h_host_2_goal', 'h_host_3_goal', 'h_host_4_goal', 'h_host_5_goal',
#        'h_host_6_goal', 'h_host_7_goal', 'v_score', 'v_rank',
#        'v_perf_win', 'v_perf_draw', 'v_perf_lose', 'v_host_win',
#        'v_host_draw', 'v_host_lose', 'v_battle_with_front_10_win',
#        'v_battle_with_front_10_draw', 'v_battle_with_front_10_lose',
#        'v_battle_with_end_10_win', 'v_battle_with_end_10_draw',
#        'v_battle_with_end_10_lose', 'v_perf_gs', 'v_perf_gd',
#        'v_perf_avg_gs', 'v_perf_avg_gd', 'v_host_gs', 'v_host_gd',
#        'v_host_avg_gs', 'v_host_avg_gd', 'v_r3_gs', 'v_r3_gd',
#        'v_r3_avg_gs', 'v_r3_avg_gd', 'v_perf_bet_high', 'v_perf_bet_low',
#        'v_host_bet_high', 'v_host_bet_low', 'v_host_0_1_goal',
#        'v_host_2_3_goal', 'v_host_ab_4_goal', 'v_host_0_goal',
#        'v_host_1_goal', 'v_host_2_goal', 'v_host_3_goal', 'v_host_4_goal',
#        'v_host_5_goal', 'v_host_6_goal', 'v_host_7_goal',
#        'h_perf_win_count', 'h_perf_draw_count', 'h_perf_lose_count',
#        'h_host_win_count', 'h_host_draw_count', 'h_host_lose_count',
#        'h_battle_with_front_10_win_count',
#        'h_battle_with_front_10_draw_count',
#        'h_battle_with_front_10_lose_count',
#        'h_battle_with_end_10_win_count',
#        'h_battle_with_end_10_draw_count',
#        'h_battle_with_end_10_lose_count', 'v_perf_win_count',
#        'v_perf_draw_count', 'v_perf_lose_count', 'v_host_win_count',
#        'v_host_draw_count', 'v_host_lose_count',
#        'v_battle_with_front_10_win_count',
#        'v_battle_with_front_10_draw_count',
#        'v_battle_with_front_10_lose_count',
#        'v_battle_with_end_10_win_count',
#        'v_battle_with_end_10_draw_count',
#        'v_battle_with_end_10_lose_count'], dtype=object)

# %%
def get_count(col):
    arr = col.split(' ')
    if len(arr) == 2:
        return int(arr[1])
    
    return int(arr[0])

# %%
features_df['h_perf_win_count'] = features_df.apply(lambda row: get_count(row.h_perf_win), axis=1)
features_df['h_perf_draw_count'] = features_df.apply(lambda row: get_count(row.h_perf_draw), axis=1)
features_df['h_perf_lose_count'] = features_df.apply(lambda row: get_count(row.h_perf_lose), axis=1)
features_df['h_host_win_count'] = features_df.apply(lambda row: get_count(row.h_host_win), axis=1)
features_df['h_host_draw_count'] = features_df.apply(lambda row: get_count(row.h_host_draw), axis=1)
features_df['h_host_lose_count'] = features_df.apply(lambda row: get_count(row.h_host_lose), axis=1)
features_df['h_battle_with_front_10_win_count'] = features_df.apply(lambda row: get_count(row.h_battle_with_front_10_win), axis=1)
features_df['h_battle_with_front_10_draw_count'] = features_df.apply(lambda row: get_count(row.h_battle_with_front_10_draw), axis=1)
features_df['h_battle_with_front_10_lose_count'] = features_df.apply(lambda row: get_count(row.h_battle_with_front_10_lose), axis=1)
features_df['h_battle_with_end_10_win_count'] = features_df.apply(lambda row: get_count(row.h_battle_with_end_10_win), axis=1)
features_df['h_battle_with_end_10_draw_count'] = features_df.apply(lambda row: get_count(row.h_battle_with_end_10_draw), axis=1)
features_df['h_battle_with_end_10_lose_count'] = features_df.apply(lambda row: get_count(row.h_battle_with_end_10_lose), axis=1)

features_df['v_perf_win_count'] = features_df.apply(lambda row: get_count(row.v_perf_win), axis=1)
features_df['v_perf_draw_count'] = features_df.apply(lambda row: get_count(row.v_perf_draw), axis=1)
features_df['v_perf_lose_count'] = features_df.apply(lambda row: get_count(row.v_perf_lose), axis=1)
features_df['v_host_win_count'] = features_df.apply(lambda row: get_count(row.v_host_win), axis=1)
features_df['v_host_draw_count'] = features_df.apply(lambda row: get_count(row.v_host_draw), axis=1)
features_df['v_host_lose_count'] = features_df.apply(lambda row: get_count(row.v_host_lose), axis=1)
features_df['v_battle_with_front_10_win_count'] = features_df.apply(lambda row: get_count(row.v_battle_with_front_10_win), axis=1)
features_df['v_battle_with_front_10_draw_count'] = features_df.apply(lambda row: get_count(row.v_battle_with_front_10_draw), axis=1)
features_df['v_battle_with_front_10_lose_count'] = features_df.apply(lambda row: get_count(row.v_battle_with_front_10_lose), axis=1)
features_df['v_battle_with_end_10_win_count'] = features_df.apply(lambda row: get_count(row.v_battle_with_end_10_win), axis=1)
features_df['v_battle_with_end_10_draw_count'] = features_df.apply(lambda row: get_count(row.v_battle_with_end_10_draw), axis=1)
features_df['v_battle_with_end_10_lose_count'] = features_df.apply(lambda row: get_count(row.v_battle_with_end_10_lose), axis=1)

# %% [markdown]
# ## 处理list表数据

# %%
df = pd.read_csv('../data/breadt_football_game_list_201904221023.csv', parse_dates=['time'])

# match_df = df
match_group = ['澳超', '英超', '德甲', '德乙', '法甲', '西甲', '意甲', '日职', '英甲', '苏超', '法乙', '葡超', '荷甲', '荷乙', '韩K联']
match_df = df[ (df['game'].isin(match_group) ) ]

# %%
match_df.head()
# Out:
#    id  matchid status game  turn home_team visit_team  gs  gd  gn  \
# 1   2  1820486      完   澳超  第13轮       西悉尼        惠灵顿   1   3   4
# 2   3  1765894      完   英超  第20轮       斯旺西         曼城   2   3   5
# 3   4  1765886      完   英超  第20轮       阿森纳       加的夫城   2   0   2
# 4   5  1765887      完   英超  第20轮       水晶宫        诺维奇   1   1   2
# 5   6  1765888      完   英超  第20轮       富勒姆       西汉姆联   2   1   3
#
#                  time  result  win_bet_return  draw_bet_return  \
# 1 2014-01-01 08:00:00       0            1.41             4.15
# 2 2014-01-01 08:00:00       0            5.31             3.90
# 3 2014-01-01 08:00:00       3            1.25             5.86
# 4 2014-01-01 08:00:00       1            2.31             3.17
# 5 2014-01-01 08:00:00       3            2.34             3.25
#
#    lose_bet_return
# 1             7.16
# 2             1.61
# 3            11.58
# 4             3.14
# 5             3.00

# %%
len(match_df)
# Out:
# 25078

# %%
team_arr = list(set(df['home_team'].values) | set(df['visit_team'].values))

team_encoder = preprocessing.LabelEncoder()
team_encoder.fit(team_arr)

match_df['home_team_encoder'] = team_encoder.transform(match_df['home_team'])
match_df['visit_team_encoder'] = team_encoder.transform(match_df['visit_team'])
# Out:
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
game_arr = list(set(match_df['game'].values))

game_encoder = preprocessing.LabelEncoder()
game_encoder.fit(game_arr)

match_df['game_encoder'] = game_encoder.transform(match_df['game'])
# Out:
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
match_df['year'] = match_df.apply(lambda row: row.time.year, axis=1)
match_df['month'] = match_df.apply(lambda row: row.time.month, axis=1)
match_df['day'] = match_df.apply(lambda row: row.time.day, axis=1)
# Out:
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
match_df['fix_result'] = match_df.apply(lambda row: int(row.result) if row.result < 3 else 2, axis=1)
# Out:
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
match_df.columns
# Out:
# Index(['id', 'matchid', 'status', 'game', 'turn', 'home_team', 'visit_team',
#        'gs', 'gd', 'gn', 'time', 'result', 'win_bet_return', 'draw_bet_return',
#        'lose_bet_return', 'home_team_encoder', 'visit_team_encoder',
#        'game_encoder', 'year', 'month', 'day', 'fix_result'],
#       dtype='object')

# %%
match_df.head()
# Out:
#    id  matchid status game  turn home_team visit_team  gs  gd  gn  ...  \
# 1   2  1820486      完   澳超  第13轮       西悉尼        惠灵顿   1   3   4  ...
# 2   3  1765894      完   英超  第20轮       斯旺西         曼城   2   3   5  ...
# 3   4  1765886      完   英超  第20轮       阿森纳       加的夫城   2   0   2  ...
# 4   5  1765887      完   英超  第20轮       水晶宫        诺维奇   1   1   2  ...
# 5   6  1765888      完   英超  第20轮       富勒姆       西汉姆联   2   1   3  ...
#
#   win_bet_return  draw_bet_return  lose_bet_return  home_team_encoder  \
# 1           1.41             4.15             7.16               1458
# 2           5.31             3.90             1.61                833
# 3           1.25             5.86            11.58               1614
# 4           2.31             3.17             3.14                983
# 5           2.34             3.25             3.00                597
#
#    visit_team_encoder  game_encoder  year  month  day  fix_result
# 1                 764             6  2014      1    1           0
# 2                 886             9  2014      1    1           0
# 3                 215             9  2014      1    1           2
# 4                1471             9  2014      1    1           1
# 5                1459             9  2014      1    1           2
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 并表

# %%
train_dataset_df = pd.merge(match_df, features_df, on='matchid', how='left')

# %%
train_dataset_df = train_dataset_df.dropna()

# %%
train_dataset_df.head()
# Out:
#    id_x  matchid status game  turn home_team visit_team  gs  gd  gn  ...  \
# 0     2  1820486      完   澳超  第13轮       西悉尼        惠灵顿   1   3   4  ...
# 1     3  1765894      完   英超  第20轮       斯旺西         曼城   2   3   5  ...
# 2     4  1765886      完   英超  第20轮       阿森纳       加的夫城   2   0   2  ...
# 3     5  1765887      完   英超  第20轮       水晶宫        诺维奇   1   1   2  ...
# 4     6  1765888      完   英超  第20轮       富勒姆       西汉姆联   2   1   3  ...
#
#   v_perf_lose_count  v_host_win_count  v_host_draw_count  v_host_lose_count  \
# 0                 6                 2                  1                  4
# 1                 4                 4                  2                  4
# 2                10                 1                  3                  6
# 3                10                 2                  2                  6
# 4                11                 1                  3                  6
#
#    v_battle_with_front_10_win_count  v_battle_with_front_10_draw_count  \
# 0                                 3                                  4
# 1                                 6                                  2
# 2                                 1                                  3
# 3                                 2                                  1
# 4                                 1                                  2
#
#    v_battle_with_front_10_lose_count  v_battle_with_end_10_win_count  \
# 0                                  6                               3
# 1                                  1                               8
# 2                                  7                               3
# 3                                  7                               3
# 4                                  7                               2
#
#    v_battle_with_end_10_draw_count  v_battle_with_end_10_lose_count
# 0                                4                                6
# 1                                0                                3
# 2                                3                                3
# 3                                4                                3
# 4                                4                                4
#
# [5 rows x 129 columns]

# %% [markdown]
# ## 训练 xgb

# %%
import xgboost as xgb

x_columns = [
    'year', 
    'month', 
#     'day',
    'win_bet_return', 'draw_bet_return','lose_bet_return', 'home_team_encoder', 'visit_team_encoder', 'game_encoder',
    'h_perf_gs', 'h_perf_gd', 'h_perf_avg_gs', 'h_perf_avg_gd',
    'h_host_gs', 'h_host_gd', 'h_host_avg_gs', 'h_host_avg_gd',
    'h_r3_gs', 'h_r3_gd', 'h_r3_avg_gs', 'h_r3_avg_gd',
    'h_perf_bet_high', 'h_perf_bet_low', 'h_host_bet_high',
    'h_host_bet_low', 'h_host_0_1_goal', 'h_host_2_3_goal',
    'h_host_ab_4_goal', 'h_host_0_goal', 'h_host_1_goal',
    'h_host_2_goal', 'h_host_3_goal', 'h_host_4_goal', 'h_host_5_goal',
    'h_host_6_goal', 'h_host_7_goal', 

    'v_perf_gs', 'v_perf_gd',
    'v_perf_avg_gs', 'v_perf_avg_gd', 'v_host_gs', 'v_host_gd',
    'v_host_avg_gs', 'v_host_avg_gd', 'v_r3_gs', 'v_r3_gd',
    'v_r3_avg_gs', 'v_r3_avg_gd', 'v_perf_bet_high', 'v_perf_bet_low',
    'v_host_bet_high', 'v_host_bet_low', 'v_host_0_1_goal',
    'v_host_2_3_goal', 'v_host_ab_4_goal', 'v_host_0_goal',
    'v_host_1_goal', 'v_host_2_goal', 'v_host_3_goal', 'v_host_4_goal',
    'v_host_5_goal', 'v_host_6_goal', 'v_host_7_goal',

    'h_perf_win_count', 'h_perf_draw_count', 'h_perf_lose_count',
    'h_host_win_count', 'h_host_draw_count', 'h_host_lose_count',
    'h_battle_with_front_10_win_count',
    'h_battle_with_front_10_draw_count',
    'h_battle_with_front_10_lose_count',
    'h_battle_with_end_10_win_count',
    'h_battle_with_end_10_draw_count',
    'h_battle_with_end_10_lose_count', 'v_perf_win_count',
    'v_perf_draw_count', 'v_perf_lose_count', 'v_host_win_count',
    'v_host_draw_count', 'v_host_lose_count',
    'v_battle_with_front_10_win_count',
    'v_battle_with_front_10_draw_count',
    'v_battle_with_front_10_lose_count',
    'v_battle_with_end_10_win_count',
    'v_battle_with_end_10_draw_count',
    'v_battle_with_end_10_lose_count']
    
params={
    'booster':'gbtree',
    # 这里手写数字是0-9，是一个多类的问题，因此采用了multisoft多分类器，
    'objective': 'multi:softmax', 
    'num_class':3, # 类数，与 multisoftmax 并用
    'gamma':0.1,  # 在树的叶子节点下一个分区的最小损失，越大算法模型越保守 。[0:]
    'max_depth':12, # 构建树的深度 [1:]
    #'lambda':450,  # L2 正则项权重
    'subsample':0.7, # 采样训练数据，设置为0.5，随机选择一般的数据实例 (0:1]
    'colsample_bytree':0.7, # 构建树树时的采样比率 (0:1]
    #'min_child_weight':12, # 节点的最少特征数
    'silent':1 ,
    'eta': 0.05, # 如同学习率
    'seed':710,
    'nthread':4,# cpu 线程数,根据自己U的个数适当调整
}

train_dataset = train_dataset_df[train_dataset_df['year'] < 2019]
test_dataset = train_dataset_df[train_dataset_df['year'] == 2019]

xgtrain = xgb.DMatrix(train_dataset[x_columns], label=train_dataset['fix_result'])
xgtest = xgb.DMatrix(test_dataset[x_columns], label=test_dataset['fix_result'])

watchlist = [(xgtrain, 'train'),(xgtest, 'val')]

# num_rounds = 10000
# stop_rounds = 100

num_rounds = 10000
stop_rounds = 100

model = xgb.train(params, xgtrain, num_rounds, watchlist,early_stopping_rounds=stop_rounds)
print(model.best_iteration)

preds = model.predict(xgtest, ntree_limit=model.best_iteration)
preds
# Out:
# [0]	train-merror:0.179962	val-merror:0.360352
# Multiple eval metrics have been passed: 'val-merror' will be used for early stopping.
#
# Will train until val-merror hasn't improved in 100 rounds.
# [1]	train-merror:0.137586	val-merror:0.3163
# [2]	train-merror:0.125329	val-merror:0.307489
# [3]	train-merror:0.113491	val-merror:0.302203
# [4]	train-merror:0.109559	val-merror:0.297797
# [5]	train-merror:0.102238	val-merror:0.298678
# [6]	train-merror:0.100272	val-merror:0.296035
# [7]	train-merror:0.095127	val-merror:0.304846
# [8]	train-merror:0.09224	val-merror:0.300441
# [9]	train-merror:0.090107	val-merror:0.302203
# [10]	train-merror:0.090316	val-merror:0.300441
# [11]	train-merror:0.088266	val-merror:0.295154
# [12]	train-merror:0.087848	val-merror:0.299559
# [13]	train-merror:0.084376	val-merror:0.290749
# [14]	train-merror:0.082619	val-merror:0.299559
# [15]	train-merror:0.080485	val-merror:0.296035
# [16]	train-merror:0.080192	val-merror:0.296916
# [17]	train-merror:0.078686	val-merror:0.289868
# [18]	train-merror:0.07693	val-merror:0.289868
# [19]	train-merror:0.076135	val-merror:0.292511
# [20]	train-merror:0.074085	val-merror:0.287225
# [21]	train-merror:0.07329	val-merror:0.289868
# [22]	train-merror:0.071659	val-merror:0.289868
# [23]	train-merror:0.07124	val-merror:0.288106
# [24]	train-merror:0.069316	val-merror:0.285463
# [25]	train-merror:0.067517	val-merror:0.286344
# [26]	train-merror:0.065718	val-merror:0.285463
# [27]	train-merror:0.065175	val-merror:0.2837
# [28]	train-merror:0.063543	val-merror:0.2837
# [29]	train-merror:0.062832	val-merror:0.281057
# [30]	train-merror:0.062079	val-merror:0.2837
# [31]	train-merror:0.060113	val-merror:0.278414
# [32]	train-merror:0.059067	val-merror:0.280176
# [33]	train-merror:0.058105	val-merror:0.276652
# [34]	train-merror:0.056683	val-merror:0.27489
# [35]	train-merror:0.056097	val-merror:0.27489
# [36]	train-merror:0.054507	val-merror:0.273128
# [37]	train-merror:0.053169	val-merror:0.278414
# [38]	train-merror:0.052876	val-merror:0.281938
# [39]	train-merror:0.051286	val-merror:0.276652
# [40]	train-merror:0.05091	val-merror:0.273128
# [41]	train-merror:0.049488	val-merror:0.27489
# [42]	train-merror:0.048484	val-merror:0.274009
# [43]	train-merror:0.047647	val-merror:0.275771
# [44]	train-merror:0.046727	val-merror:0.271366
# [45]	train-merror:0.046141	val-merror:0.272247
# [46]	train-merror:0.045388	val-merror:0.271366
# [47]	train-merror:0.043966	val-merror:0.272247
# [48]	train-merror:0.043087	val-merror:0.266079
# [49]	train-merror:0.042292	val-merror:0.266079
# [50]	train-merror:0.041414	val-merror:0.26696
# [51]	train-merror:0.040535	val-merror:0.266079
# [52]	train-merror:0.039908	val-merror:0.26696
# [53]	train-merror:0.039364	val-merror:0.267841
# [54]	train-merror:0.038737	val-merror:0.266079
# [55]	train-merror:0.038067	val-merror:0.26696
# [56]	train-merror:0.037482	val-merror:0.269604
# [57]	train-merror:0.03652	val-merror:0.267841
# [58]	train-merror:0.035432	val-merror:0.270485
# [59]	train-merror:0.034721	val-merror:0.272247
# [60]	train-merror:0.034135	val-merror:0.267841
# [61]	train-merror:0.033257	val-merror:0.267841
# [62]	train-merror:0.032755	val-merror:0.266079
# [63]	train-merror:0.032462	val-merror:0.26696
# [64]	train-merror:0.031416	val-merror:0.265198
# [65]	train-merror:0.030956	val-merror:0.264317
# [66]	train-merror:0.030245	val-merror:0.264317
# [67]	train-merror:0.029952	val-merror:0.265198
# [68]	train-merror:0.029241	val-merror:0.266079
# [69]	train-merror:0.028781	val-merror:0.266079
# [70]	train-merror:0.028404	val-merror:0.263436
# [71]	train-merror:0.027693	val-merror:0.265198
# [72]	train-merror:0.027275	val-merror:0.26696
# [73]	train-merror:0.026563	val-merror:0.267841
# [74]	train-merror:0.026145	val-merror:0.26696
# [75]	train-merror:0.025476	val-merror:0.266079
# [76]	train-merror:0.024765	val-merror:0.268722
# [77]	train-merror:0.024054	val-merror:0.267841
# [78]	train-merror:0.02397	val-merror:0.268722
# [79]	train-merror:0.023468	val-merror:0.265198
# [80]	train-merror:0.022673	val-merror:0.267841
# [81]	train-merror:0.022506	val-merror:0.265198
# [82]	train-merror:0.02192	val-merror:0.26696
# [83]	train-merror:0.021418	val-merror:0.269604
# [84]	train-merror:0.020874	val-merror:0.265198
# [85]	train-merror:0.020205	val-merror:0.268722
# [86]	train-merror:0.019828	val-merror:0.265198
# [87]	train-merror:0.019243	val-merror:0.266079
# [88]	train-merror:0.018574	val-merror:0.264317
# [89]	train-merror:0.018364	val-merror:0.261674
# [90]	train-merror:0.017862	val-merror:0.259912
# [91]	train-merror:0.017737	val-merror:0.262555
# [92]	train-merror:0.017151	val-merror:0.260793
# [93]	train-merror:0.016524	val-merror:0.261674
# [94]	train-merror:0.016356	val-merror:0.26696
# [95]	train-merror:0.016315	val-merror:0.263436
# [96]	train-merror:0.016022	val-merror:0.264317
# [97]	train-merror:0.015603	val-merror:0.267841
# [98]	train-merror:0.015394	val-merror:0.264317
# [99]	train-merror:0.01506	val-merror:0.261674
# [100]	train-merror:0.014558	val-merror:0.262555
# [101]	train-merror:0.01393	val-merror:0.262555
# [102]	train-merror:0.013805	val-merror:0.260793
# [103]	train-merror:0.013554	val-merror:0.260793
# [104]	train-merror:0.01301	val-merror:0.261674
# [105]	train-merror:0.012926	val-merror:0.262555
# [106]	train-merror:0.012382	val-merror:0.261674
# [107]	train-merror:0.01255	val-merror:0.261674
# [108]	train-merror:0.012006	val-merror:0.260793
# [109]	train-merror:0.011504	val-merror:0.260793
# [110]	train-merror:0.011086	val-merror:0.260793
# [111]	train-merror:0.010876	val-merror:0.260793
# [112]	train-merror:0.010751	val-merror:0.259912
# [113]	train-merror:0.010374	val-merror:0.259031
# [114]	train-merror:0.010291	val-merror:0.259912
# [115]	train-merror:0.009831	val-merror:0.259912
# [116]	train-merror:0.009747	val-merror:0.260793
# [117]	train-merror:0.009287	val-merror:0.259031
# [118]	train-merror:0.00891	val-merror:0.259031
# [119]	train-merror:0.008408	val-merror:0.259031
# [120]	train-merror:0.008241	val-merror:0.261674
# [121]	train-merror:0.007906	val-merror:0.259912
# [122]	train-merror:0.007906	val-merror:0.259912
# [123]	train-merror:0.00753	val-merror:0.262555
# [124]	train-merror:0.007404	val-merror:0.264317
# [125]	train-merror:0.007195	val-merror:0.264317
# [126]	train-merror:0.007153	val-merror:0.262555
# [127]	train-merror:0.006777	val-merror:0.261674
# [128]	train-merror:0.006484	val-merror:0.264317
# [129]	train-merror:0.006359	val-merror:0.265198
# [130]	train-merror:0.006149	val-merror:0.264317
# [131]	train-merror:0.005982	val-merror:0.261674
# [132]	train-merror:0.005564	val-merror:0.263436
# [133]	train-merror:0.005355	val-merror:0.261674
# [134]	train-merror:0.005104	val-merror:0.261674
# [135]	train-merror:0.004936	val-merror:0.261674
# [136]	train-merror:0.004769	val-merror:0.264317
# [137]	train-merror:0.004643	val-merror:0.264317
# [138]	train-merror:0.004434	val-merror:0.263436
# [139]	train-merror:0.004518	val-merror:0.266079
# [140]	train-merror:0.004309	val-merror:0.26696
# [141]	train-merror:0.004267	val-merror:0.265198
# [142]	train-merror:0.004225	val-merror:0.264317
# [143]	train-merror:0.004225	val-merror:0.265198
# [144]	train-merror:0.004016	val-merror:0.265198
# [145]	train-merror:0.004016	val-merror:0.265198
# [146]	train-merror:0.003849	val-merror:0.265198
# [147]	train-merror:0.003556	val-merror:0.26696
# [148]	train-merror:0.003263	val-merror:0.267841
# [149]	train-merror:0.003347	val-merror:0.266079
# [150]	train-merror:0.003179	val-merror:0.267841
# [151]	train-merror:0.002886	val-merror:0.269604
# [152]	train-merror:0.002761	val-merror:0.270485
# [153]	train-merror:0.002761	val-merror:0.267841
# [154]	train-merror:0.002635	val-merror:0.267841
# [155]	train-merror:0.002426	val-merror:0.268722
# [156]	train-merror:0.002468	val-merror:0.267841
# [157]	train-merror:0.002384	val-merror:0.270485
# [158]	train-merror:0.002384	val-merror:0.271366
# [159]	train-merror:0.002384	val-merror:0.272247
# [160]	train-merror:0.002092	val-merror:0.269604
# [161]	train-merror:0.001966	val-merror:0.268722
# [162]	train-merror:0.001882	val-merror:0.267841
# [163]	train-merror:0.001882	val-merror:0.268722
# [164]	train-merror:0.001799	val-merror:0.268722
# [165]	train-merror:0.001631	val-merror:0.265198
# [166]	train-merror:0.00159	val-merror:0.266079
# [167]	train-merror:0.001548	val-merror:0.267841
# [168]	train-merror:0.001464	val-merror:0.267841
# [169]	train-merror:0.001422	val-merror:0.270485
# [170]	train-merror:0.001464	val-merror:0.270485
# [171]	train-merror:0.001506	val-merror:0.268722
# [172]	train-merror:0.001297	val-merror:0.268722
# [173]	train-merror:0.001297	val-merror:0.270485
# [174]	train-merror:0.001297	val-merror:0.268722
# [175]	train-merror:0.001297	val-merror:0.268722
# [176]	train-merror:0.001213	val-merror:0.268722
# [177]	train-merror:0.001171	val-merror:0.268722
# [178]	train-merror:0.001129	val-merror:0.26696
# [179]	train-merror:0.001046	val-merror:0.266079
# [180]	train-merror:0.001004	val-merror:0.268722
# [181]	train-merror:0.000962	val-merror:0.269604
# [182]	train-merror:0.000837	val-merror:0.271366
# [183]	train-merror:0.000837	val-merror:0.272247
# [184]	train-merror:0.000837	val-merror:0.271366
# [185]	train-merror:0.000837	val-merror:0.272247
# [186]	train-merror:0.000795	val-merror:0.269604
# [187]	train-merror:0.000753	val-merror:0.269604
# [188]	train-merror:0.000753	val-merror:0.269604
# [189]	train-merror:0.000711	val-merror:0.26696
# [190]	train-merror:0.000627	val-merror:0.26696
# [191]	train-merror:0.000586	val-merror:0.26696
# [192]	train-merror:0.000544	val-merror:0.267841
# [193]	train-merror:0.000544	val-merror:0.264317
# [194]	train-merror:0.000502	val-merror:0.266079
# [195]	train-merror:0.000544	val-merror:0.264317
# [196]	train-merror:0.000544	val-merror:0.262555
# [197]	train-merror:0.000502	val-merror:0.263436
# [198]	train-merror:0.000502	val-merror:0.264317
# [199]	train-merror:0.00046	val-merror:0.263436
# [200]	train-merror:0.00046	val-merror:0.261674
# [201]	train-merror:0.00046	val-merror:0.259912
# [202]	train-merror:0.000376	val-merror:0.259912
# [203]	train-merror:0.000376	val-merror:0.260793
# [204]	train-merror:0.000376	val-merror:0.262555
# [205]	train-merror:0.000293	val-merror:0.263436
# [206]	train-merror:0.000335	val-merror:0.263436
# [207]	train-merror:0.000293	val-merror:0.263436
# [208]	train-merror:0.000251	val-merror:0.260793
# [209]	train-merror:0.000209	val-merror:0.261674
# [210]	train-merror:0.000209	val-merror:0.262555
# [211]	train-merror:0.000209	val-merror:0.261674
# [212]	train-merror:0.000209	val-merror:0.260793
# [213]	train-merror:0.000209	val-merror:0.260793
# Stopping. Best iteration:
# [113]	train-merror:0.010374	val-merror:0.259031
#
# 113
# array([1., 0., 1., ..., 2., 2., 2.], dtype=float32)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_dataset['fix_result'], preds)
# Out:
# 0.7400881057268722
