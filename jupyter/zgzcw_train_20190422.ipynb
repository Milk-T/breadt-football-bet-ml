# %%
import pandas as pd
from sklearn import preprocessing

# %% [markdown]
# ## 处理feature表数据

# %%
features_df = pd.read_csv('../data/breadt_football_feature_info_201904221116.csv')

# %%
features_df.columns.values
# Out:
# array(['id', 'matchid', 'h_score', 'h_rank', 'h_perf_win', 'h_perf_draw',
#        'h_perf_lose', 'h_host_win', 'h_host_draw', 'h_host_lose',
#        'h_battle_with_front_10_win', 'h_battle_with_front_10_draw',
#        'h_battle_with_front_10_lose', 'h_battle_with_end_10_win',
#        'h_battle_with_end_10_draw', 'h_battle_with_end_10_lose',
#        'h_perf_gs', 'h_perf_gd', 'h_perf_avg_gs', 'h_perf_avg_gd',
#        'h_host_gs', 'h_host_gd', 'h_host_avg_gs', 'h_host_avg_gd',
#        'h_r3_gs', 'h_r3_gd', 'h_r3_avg_gs', 'h_r3_avg_gd',
#        'h_perf_bet_high', 'h_perf_bet_low', 'h_host_bet_high',
#        'h_host_bet_low', 'h_host_0_1_goal', 'h_host_2_3_goal',
#        'h_host_ab_4_goal', 'h_host_0_goal', 'h_host_1_goal',
#        'h_host_2_goal', 'h_host_3_goal', 'h_host_4_goal', 'h_host_5_goal',
#        'h_host_6_goal', 'h_host_7_goal', 'v_score', 'v_rank',
#        'v_perf_win', 'v_perf_draw', 'v_perf_lose', 'v_host_win',
#        'v_host_draw', 'v_host_lose', 'v_battle_with_front_10_win',
#        'v_battle_with_front_10_draw', 'v_battle_with_front_10_lose',
#        'v_battle_with_end_10_win', 'v_battle_with_end_10_draw',
#        'v_battle_with_end_10_lose', 'v_perf_gs', 'v_perf_gd',
#        'v_perf_avg_gs', 'v_perf_avg_gd', 'v_host_gs', 'v_host_gd',
#        'v_host_avg_gs', 'v_host_avg_gd', 'v_r3_gs', 'v_r3_gd',
#        'v_r3_avg_gs', 'v_r3_avg_gd', 'v_perf_bet_high', 'v_perf_bet_low',
#        'v_host_bet_high', 'v_host_bet_low', 'v_host_0_1_goal',
#        'v_host_2_3_goal', 'v_host_ab_4_goal', 'v_host_0_goal',
#        'v_host_1_goal', 'v_host_2_goal', 'v_host_3_goal', 'v_host_4_goal',
#        'v_host_5_goal', 'v_host_6_goal', 'v_host_7_goal',
#        'h_perf_win_count', 'h_perf_draw_count', 'h_perf_lose_count',
#        'h_host_win_count', 'h_host_draw_count', 'h_host_lose_count',
#        'h_battle_with_front_10_win_count',
#        'h_battle_with_front_10_draw_count',
#        'h_battle_with_front_10_lose_count',
#        'h_battle_with_end_10_win_count',
#        'h_battle_with_end_10_draw_count',
#        'h_battle_with_end_10_lose_count', 'v_perf_win_count',
#        'v_perf_draw_count', 'v_perf_lose_count', 'v_host_win_count',
#        'v_host_draw_count', 'v_host_lose_count',
#        'v_battle_with_front_10_win_count',
#        'v_battle_with_front_10_draw_count',
#        'v_battle_with_front_10_lose_count',
#        'v_battle_with_end_10_win_count',
#        'v_battle_with_end_10_draw_count',
#        'v_battle_with_end_10_lose_count', 'h_current_win_count',
#        'h_current_draw_count', 'h_current_lose_count', 'h_current_score',
#        'v_current_win_count', 'v_current_draw_count',
#        'v_current_lose_count', 'v_current_score'], dtype=object)

# %%
def get_count(col):
    arr = col.split(' ')
    if len(arr) == 2:
        return int(arr[1])
    
    return int(arr[0])

# %%
features_df['h_perf_win_count'] = features_df.apply(lambda row: get_count(row.h_perf_win), axis=1)
features_df['h_perf_draw_count'] = features_df.apply(lambda row: get_count(row.h_perf_draw), axis=1)
features_df['h_perf_lose_count'] = features_df.apply(lambda row: get_count(row.h_perf_lose), axis=1)
features_df['h_host_win_count'] = features_df.apply(lambda row: get_count(row.h_host_win), axis=1)
features_df['h_host_draw_count'] = features_df.apply(lambda row: get_count(row.h_host_draw), axis=1)
features_df['h_host_lose_count'] = features_df.apply(lambda row: get_count(row.h_host_lose), axis=1)
features_df['h_battle_with_front_10_win_count'] = features_df.apply(lambda row: get_count(row.h_battle_with_front_10_win), axis=1)
features_df['h_battle_with_front_10_draw_count'] = features_df.apply(lambda row: get_count(row.h_battle_with_front_10_draw), axis=1)
features_df['h_battle_with_front_10_lose_count'] = features_df.apply(lambda row: get_count(row.h_battle_with_front_10_lose), axis=1)
features_df['h_battle_with_end_10_win_count'] = features_df.apply(lambda row: get_count(row.h_battle_with_end_10_win), axis=1)
features_df['h_battle_with_end_10_draw_count'] = features_df.apply(lambda row: get_count(row.h_battle_with_end_10_draw), axis=1)
features_df['h_battle_with_end_10_lose_count'] = features_df.apply(lambda row: get_count(row.h_battle_with_end_10_lose), axis=1)

features_df['v_perf_win_count'] = features_df.apply(lambda row: get_count(row.v_perf_win), axis=1)
features_df['v_perf_draw_count'] = features_df.apply(lambda row: get_count(row.v_perf_draw), axis=1)
features_df['v_perf_lose_count'] = features_df.apply(lambda row: get_count(row.v_perf_lose), axis=1)
features_df['v_host_win_count'] = features_df.apply(lambda row: get_count(row.v_host_win), axis=1)
features_df['v_host_draw_count'] = features_df.apply(lambda row: get_count(row.v_host_draw), axis=1)
features_df['v_host_lose_count'] = features_df.apply(lambda row: get_count(row.v_host_lose), axis=1)
features_df['v_battle_with_front_10_win_count'] = features_df.apply(lambda row: get_count(row.v_battle_with_front_10_win), axis=1)
features_df['v_battle_with_front_10_draw_count'] = features_df.apply(lambda row: get_count(row.v_battle_with_front_10_draw), axis=1)
features_df['v_battle_with_front_10_lose_count'] = features_df.apply(lambda row: get_count(row.v_battle_with_front_10_lose), axis=1)
features_df['v_battle_with_end_10_win_count'] = features_df.apply(lambda row: get_count(row.v_battle_with_end_10_win), axis=1)
features_df['v_battle_with_end_10_draw_count'] = features_df.apply(lambda row: get_count(row.v_battle_with_end_10_draw), axis=1)
features_df['v_battle_with_end_10_lose_count'] = features_df.apply(lambda row: get_count(row.v_battle_with_end_10_lose), axis=1)

# %%
def get_current_score(words, score, pos):
    t = score.replace(words, '')
    t = t.replace('胜', '')
    t = t.replace('平', '')
    t = t.replace('负', '')
    t = t.replace('分', '')
    
    arr = t.split('  ')
    
    if len(arr) == 3 and len(arr[2].split(' ')) == 2:
        arr = [arr[0], arr[1]] + arr[2].split(' ')
    
    if len(arr) != 4:
        return None
    
    if arr[pos] != '':
        return int(arr[pos])
    else:
        return None

# %%
features_df['h_current_win_count'] = features_df.apply(lambda row: get_current_score('主队：', row.h_score, 0), axis=1)
features_df['h_current_draw_count'] = features_df.apply(lambda row: get_current_score('主队：', row.h_score, 1), axis=1)
features_df['h_current_lose_count'] = features_df.apply(lambda row: get_current_score('主队：', row.h_score, 2), axis=1)
features_df['h_current_score'] = features_df.apply(lambda row: get_current_score('主队：', row.h_score, 3), axis=1)

features_df['v_current_win_count'] = features_df.apply(lambda row: get_current_score('客队：', row.v_score, 0), axis=1)
features_df['v_current_draw_count'] = features_df.apply(lambda row: get_current_score('客队：', row.v_score, 1), axis=1)
features_df['v_current_lose_count'] = features_df.apply(lambda row: get_current_score('客队：', row.v_score, 2), axis=1)
features_df['v_current_score'] = features_df.apply(lambda row: get_current_score('客队：', row.v_score, 3), axis=1)

# %%
def get_current_rank(rank):
    arr = rank.split('  ')
    
    if len(arr) == 2:
        rank_str = arr[1].replace('本赛季排名：', '')
        if rank_str != '':
            return int(rank_str)
    
    return None

# %%
features_df['h_current_rank'] = features_df.apply(lambda row: get_current_rank(row.h_rank), axis=1)
features_df['v_current_rank'] = features_df.apply(lambda row: get_current_rank(row.v_rank), axis=1)

# %%
features_df['h_rank'].head()
# Out:
# 0         上赛季排名：12  本赛季排名：5
# 1          上赛季排名：7  本赛季排名：8
# 2    上赛季排名：[英超]18  本赛季排名：13
# 3          上赛季排名：6  本赛季排名：4
# 4        上赛季排名：11  本赛季排名：13
# Name: h_rank, dtype: object

# %%
features_df['h_rank'].head()
# Out:
# 0         上赛季排名：12  本赛季排名：5
# 1          上赛季排名：7  本赛季排名：8
# 2    上赛季排名：[英超]18  本赛季排名：13
# 3          上赛季排名：6  本赛季排名：4
# 4        上赛季排名：11  本赛季排名：13
# Name: h_rank, dtype: object

# %% [markdown]
# ## 处理list表数据

# %%
df = pd.read_csv('../data/breadt_football_game_list_201904221023.csv', parse_dates=['time'])

# match_df = df
match_group = ['澳超', '英超', '德甲', '德乙', '法甲', '西甲', '意甲', '日职', '英甲', '苏超', '法乙', '葡超', '荷甲', '荷乙', '韩K联']
match_df = df[ (df['game'].isin(match_group) ) ]
len(match_df)
# Out:
# 25078

# %%
team_arr = list(set(df['home_team'].values) | set(df['visit_team'].values))

team_encoder = preprocessing.LabelEncoder()
team_encoder.fit(team_arr)

match_df['home_team_encoder'] = team_encoder.transform(match_df['home_team'])
match_df['visit_team_encoder'] = team_encoder.transform(match_df['visit_team'])
# Out:
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
game_arr = list(set(match_df['game'].values))

game_encoder = preprocessing.LabelEncoder()
game_encoder.fit(game_arr)

match_df['game_encoder'] = game_encoder.transform(match_df['game'])
# Out:
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
match_df['year'] = match_df.apply(lambda row: row.time.year, axis=1)
match_df['month'] = match_df.apply(lambda row: row.time.month, axis=1)
match_df['day'] = match_df.apply(lambda row: row.time.day, axis=1)
match_df['fix_result'] = match_df.apply(lambda row: int(row.result) if row.result < 3 else 2, axis=1)
# Out:
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ## 并表

# %%
train_dataset_df = pd.merge(match_df, features_df, on='matchid', how='left')

# %%
train_dataset_df = train_dataset_df.dropna()
len(train_dataset_df)
# Out:
# 24472

# %%
train_dataset_df.head()
# Out:
#    id_x  matchid status game  turn home_team visit_team  gs  gd  gn  ...  \
# 0     2  1820486      完   澳超  第13轮       西悉尼        惠灵顿   1   3   4  ...
# 1     3  1765894      完   英超  第20轮       斯旺西         曼城   2   3   5  ...
# 2     4  1765886      完   英超  第20轮       阿森纳       加的夫城   2   0   2  ...
# 3     5  1765887      完   英超  第20轮       水晶宫        诺维奇   1   1   2  ...
# 4     6  1765888      完   英超  第20轮       富勒姆       西汉姆联   2   1   3  ...
#
#   h_current_win_count  h_current_draw_count  h_current_lose_count  \
# 0                 6.0                   6.0                  13.0
# 1                16.0                   8.0                  17.0
# 2                20.0                   6.0                   7.0
# 3                11.0                   6.0                  17.0
# 4                 5.0                   5.0                  24.0
#
#    h_current_score  v_current_win_count  v_current_draw_count  \
# 0             24.0                 10.0                   7.0
# 1             56.0                 27.0                   2.0
# 2             66.0                  8.0                   4.0
# 3             39.0                 25.0                  11.0
# 4             20.0                 12.0                   6.0
#
#    v_current_lose_count  v_current_score  h_current_rank  v_current_rank
# 0                   8.0             37.0             8.0             5.0
# 1                   4.0             83.0            13.0             2.0
# 2                  21.0             28.0             4.0            18.0
# 3                   6.0             86.0            13.0             1.0
# 4                  16.0             42.0            19.0            11.0
#
# [5 rows x 139 columns]

# %% [markdown]
# ## 训练 xgb

# %%
import xgboost as xgb

x_columns = [
    'year', 
    'month', 
#     'day',
    'win_bet_return', 'draw_bet_return','lose_bet_return', 'home_team_encoder', 'visit_team_encoder', 'game_encoder',
    'h_perf_gs', 'h_perf_gd', 'h_perf_avg_gs', 'h_perf_avg_gd',
    'h_host_gs', 'h_host_gd', 'h_host_avg_gs', 'h_host_avg_gd',
    'h_r3_gs', 'h_r3_gd', 'h_r3_avg_gs', 'h_r3_avg_gd',
    'h_perf_bet_high', 'h_perf_bet_low', 'h_host_bet_high',
    'h_host_bet_low', 'h_host_0_1_goal', 'h_host_2_3_goal',
    'h_host_ab_4_goal', 'h_host_0_goal', 'h_host_1_goal',
    'h_host_2_goal', 'h_host_3_goal', 'h_host_4_goal', 'h_host_5_goal',
    'h_host_6_goal', 'h_host_7_goal', 

    'v_perf_gs', 'v_perf_gd',
    'v_perf_avg_gs', 'v_perf_avg_gd', 'v_host_gs', 'v_host_gd',
    'v_host_avg_gs', 'v_host_avg_gd', 'v_r3_gs', 'v_r3_gd',
    'v_r3_avg_gs', 'v_r3_avg_gd', 'v_perf_bet_high', 'v_perf_bet_low',
    'v_host_bet_high', 'v_host_bet_low', 'v_host_0_1_goal',
    'v_host_2_3_goal', 'v_host_ab_4_goal', 'v_host_0_goal',
    'v_host_1_goal', 'v_host_2_goal', 'v_host_3_goal', 'v_host_4_goal',
    'v_host_5_goal', 'v_host_6_goal', 'v_host_7_goal',

    'h_perf_win_count', 'h_perf_draw_count', 'h_perf_lose_count',
    'h_host_win_count', 'h_host_draw_count', 'h_host_lose_count',
    'h_battle_with_front_10_win_count',
    'h_battle_with_front_10_draw_count',
    'h_battle_with_front_10_lose_count',
    'h_battle_with_end_10_win_count',
    'h_battle_with_end_10_draw_count',
    'h_battle_with_end_10_lose_count', 'v_perf_win_count',
    'v_perf_draw_count', 'v_perf_lose_count', 'v_host_win_count',
    'v_host_draw_count', 'v_host_lose_count',
    'v_battle_with_front_10_win_count',
    'v_battle_with_front_10_draw_count',
    'v_battle_with_front_10_lose_count',
    'v_battle_with_end_10_win_count',
    'v_battle_with_end_10_draw_count',
    'v_battle_with_end_10_lose_count',
    'h_current_win_count',
    'h_current_draw_count', 'h_current_lose_count', 'h_current_score',
    'v_current_win_count', 'v_current_draw_count',
    'v_current_lose_count', 'v_current_score',
    'h_current_rank', 'v_current_rank']
    
params={
    'booster':'gbtree',
    # 这里手写数字是0-9，是一个多类的问题，因此采用了multisoft多分类器，
    'objective': 'multi:softmax', 
    'num_class':3, # 类数，与 multisoftmax 并用
    'gamma':0.1,  # 在树的叶子节点下一个分区的最小损失，越大算法模型越保守 。[0:]
    'max_depth':8, # 构建树的深度 [1:]
    #'lambda':450,  # L2 正则项权重
    'subsample':0.7, # 采样训练数据，设置为0.5，随机选择一般的数据实例 (0:1]
    'colsample_bytree':0.7, # 构建树树时的采样比率 (0:1]
    #'min_child_weight':12, # 节点的最少特征数
    'silent':1 ,
    'eta': 0.05, # 如同学习率
    'seed':710,
    'nthread':4,# cpu 线程数,根据自己U的个数适当调整
}

train_dataset = train_dataset_df[train_dataset_df['year'] < 2019]
test_dataset = train_dataset_df[train_dataset_df['year'] == 2019]

xgtrain = xgb.DMatrix(train_dataset[x_columns], label=train_dataset['fix_result'])
xgtest = xgb.DMatrix(test_dataset[x_columns], label=test_dataset['fix_result'])

watchlist = [(xgtrain, 'train'),(xgtest, 'val')]

# num_rounds = 10000
# stop_rounds = 100

num_rounds = 10000
stop_rounds = 100

model = xgb.train(params, xgtrain, num_rounds, watchlist,early_stopping_rounds=stop_rounds)
print(model.best_iteration)

preds = model.predict(xgtest, ntree_limit=model.best_iteration)
preds
# Out:
# [0]	train-merror:0.250675	val-merror:0.314537
# Multiple eval metrics have been passed: 'val-merror' will be used for early stopping.
#
# Will train until val-merror hasn't improved in 100 rounds.
# [1]	train-merror:0.233706	val-merror:0.30837
# [2]	train-merror:0.225136	val-merror:0.297797
# [3]	train-merror:0.221537	val-merror:0.301322
# [4]	train-merror:0.218708	val-merror:0.302203
# [5]	train-merror:0.217766	val-merror:0.302203
# [6]	train-merror:0.214552	val-merror:0.304846
# [7]	train-merror:0.212495	val-merror:0.301322
# [8]	train-merror:0.211167	val-merror:0.296916
# [9]	train-merror:0.210224	val-merror:0.297797
# [10]	train-merror:0.210053	val-merror:0.296035
# [11]	train-merror:0.207567	val-merror:0.296035
# [12]	train-merror:0.208039	val-merror:0.298678
# [13]	train-merror:0.206753	val-merror:0.302203
# [14]	train-merror:0.205982	val-merror:0.297797
# [15]	train-merror:0.205082	val-merror:0.297797
# [16]	train-merror:0.204439	val-merror:0.295154
# [17]	train-merror:0.203282	val-merror:0.295154
# [18]	train-merror:0.202811	val-merror:0.289868
# [19]	train-merror:0.20174	val-merror:0.2837
# [20]	train-merror:0.201697	val-merror:0.284582
# [21]	train-merror:0.200668	val-merror:0.285463
# [22]	train-merror:0.200154	val-merror:0.286344
# [23]	train-merror:0.198397	val-merror:0.284582
# [24]	train-merror:0.198012	val-merror:0.285463
# [25]	train-merror:0.197669	val-merror:0.2837
# [26]	train-merror:0.196126	val-merror:0.286344
# [27]	train-merror:0.195312	val-merror:0.284582
# [28]	train-merror:0.194755	val-merror:0.285463
# [29]	train-merror:0.194155	val-merror:0.285463
# [30]	train-merror:0.194112	val-merror:0.2837
# [31]	train-merror:0.193812	val-merror:0.2837
# [32]	train-merror:0.193255	val-merror:0.282819
# [33]	train-merror:0.192613	val-merror:0.282819
# [34]	train-merror:0.192056	val-merror:0.285463
# [35]	train-merror:0.191413	val-merror:0.285463
# [36]	train-merror:0.191241	val-merror:0.282819
# [37]	train-merror:0.189784	val-merror:0.2837
# [38]	train-merror:0.189227	val-merror:0.282819
# [39]	train-merror:0.188156	val-merror:0.281057
# [40]	train-merror:0.187513	val-merror:0.280176
# [41]	train-merror:0.185842	val-merror:0.281057
# [42]	train-merror:0.185757	val-merror:0.280176
# [43]	train-merror:0.184514	val-merror:0.278414
# [44]	train-merror:0.184342	val-merror:0.277533
# [45]	train-merror:0.183443	val-merror:0.279295
# [46]	train-merror:0.181943	val-merror:0.277533
# [47]	train-merror:0.1819	val-merror:0.275771
# [48]	train-merror:0.181172	val-merror:0.27489
# [49]	train-merror:0.179886	val-merror:0.276652
# [50]	train-merror:0.178772	val-merror:0.274009
# [51]	train-merror:0.178686	val-merror:0.27489
# [52]	train-merror:0.178986	val-merror:0.273128
# [53]	train-merror:0.178001	val-merror:0.269604
# [54]	train-merror:0.177186	val-merror:0.269604
# [55]	train-merror:0.176158	val-merror:0.268722
# [56]	train-merror:0.175558	val-merror:0.267841
# [57]	train-merror:0.174873	val-merror:0.267841
# [58]	train-merror:0.17453	val-merror:0.268722
# [59]	train-merror:0.17423	val-merror:0.269604
# [60]	train-merror:0.173458	val-merror:0.270485
# [61]	train-merror:0.172044	val-merror:0.269604
# [62]	train-merror:0.171873	val-merror:0.270485
# [63]	train-merror:0.171273	val-merror:0.270485
# [64]	train-merror:0.171316	val-merror:0.271366
# [65]	train-merror:0.170759	val-merror:0.273128
# [66]	train-merror:0.169431	val-merror:0.273128
# [67]	train-merror:0.168745	val-merror:0.273128
# [68]	train-merror:0.168402	val-merror:0.273128
# [69]	train-merror:0.167802	val-merror:0.271366
# [70]	train-merror:0.167502	val-merror:0.273128
# [71]	train-merror:0.166774	val-merror:0.272247
# [72]	train-merror:0.166174	val-merror:0.273128
# [73]	train-merror:0.165745	val-merror:0.270485
# [74]	train-merror:0.165145	val-merror:0.269604
# [75]	train-merror:0.164931	val-merror:0.270485
# [76]	train-merror:0.163946	val-merror:0.270485
# [77]	train-merror:0.163003	val-merror:0.269604
# [78]	train-merror:0.161632	val-merror:0.271366
# [79]	train-merror:0.161118	val-merror:0.271366
# [80]	train-merror:0.160475	val-merror:0.270485
# [81]	train-merror:0.160261	val-merror:0.269604
# [82]	train-merror:0.159361	val-merror:0.267841
# [83]	train-merror:0.159275	val-merror:0.26696
# [84]	train-merror:0.158547	val-merror:0.268722
# [85]	train-merror:0.157604	val-merror:0.264317
# [86]	train-merror:0.157261	val-merror:0.264317
# [87]	train-merror:0.156533	val-merror:0.265198
# [88]	train-merror:0.156404	val-merror:0.265198
# [89]	train-merror:0.155461	val-merror:0.264317
# [90]	train-merror:0.154733	val-merror:0.265198
# [91]	train-merror:0.15409	val-merror:0.260793
# [92]	train-merror:0.154133	val-merror:0.259912
# [93]	train-merror:0.154047	val-merror:0.260793
# [94]	train-merror:0.153533	val-merror:0.260793
# [95]	train-merror:0.153447	val-merror:0.259912
# [96]	train-merror:0.152805	val-merror:0.260793
# [97]	train-merror:0.151433	val-merror:0.260793
# [98]	train-merror:0.151219	val-merror:0.259912
# [99]	train-merror:0.150876	val-merror:0.259912
# [100]	train-merror:0.149934	val-merror:0.260793
# [101]	train-merror:0.149119	val-merror:0.259031
# [102]	train-merror:0.14852	val-merror:0.259031
# [103]	train-merror:0.147705	val-merror:0.259912
# [104]	train-merror:0.146805	val-merror:0.259912
# [105]	train-merror:0.146548	val-merror:0.25815
# [106]	train-merror:0.146248	val-merror:0.259912
# [107]	train-merror:0.14582	val-merror:0.25815
# [108]	train-merror:0.145349	val-merror:0.257269
# [109]	train-merror:0.145006	val-merror:0.257269
# [110]	train-merror:0.143763	val-merror:0.257269
# [111]	train-merror:0.143549	val-merror:0.25815
# [112]	train-merror:0.142435	val-merror:0.257269
# [113]	train-merror:0.142049	val-merror:0.256388
# [114]	train-merror:0.141835	val-merror:0.256388
# [115]	train-merror:0.141064	val-merror:0.25815
# [116]	train-merror:0.140078	val-merror:0.25815
# [117]	train-merror:0.139521	val-merror:0.25815
# [118]	train-merror:0.13935	val-merror:0.25815
# [119]	train-merror:0.138407	val-merror:0.25815
# [120]	train-merror:0.137893	val-merror:0.257269
# [121]	train-merror:0.137293	val-merror:0.257269
# [122]	train-merror:0.136264	val-merror:0.256388
# [123]	train-merror:0.135921	val-merror:0.256388
# [124]	train-merror:0.135407	val-merror:0.25815
# [125]	train-merror:0.134422	val-merror:0.25815
# [126]	train-merror:0.13395	val-merror:0.25815
# [127]	train-merror:0.13365	val-merror:0.259912
# [128]	train-merror:0.13335	val-merror:0.259031
# [129]	train-merror:0.132279	val-merror:0.259031
# [130]	train-merror:0.131551	val-merror:0.25815
# [131]	train-merror:0.131379	val-merror:0.259912
# [132]	train-merror:0.130651	val-merror:0.261674
# [133]	train-merror:0.130351	val-merror:0.261674
# [134]	train-merror:0.129751	val-merror:0.260793
# [135]	train-merror:0.12928	val-merror:0.260793
# [136]	train-merror:0.129065	val-merror:0.262555
# [137]	train-merror:0.12838	val-merror:0.261674
# [138]	train-merror:0.127223	val-merror:0.259031
# [139]	train-merror:0.12688	val-merror:0.259912
# [140]	train-merror:0.12628	val-merror:0.259031
# [141]	train-merror:0.124866	val-merror:0.259031
# [142]	train-merror:0.124395	val-merror:0.259912
# [143]	train-merror:0.123795	val-merror:0.259031
# [144]	train-merror:0.123238	val-merror:0.259031
# [145]	train-merror:0.121738	val-merror:0.259912
# [146]	train-merror:0.121824	val-merror:0.259912
# [147]	train-merror:0.12131	val-merror:0.259031
# [148]	train-merror:0.120538	val-merror:0.259031
# [149]	train-merror:0.120024	val-merror:0.25815
# [150]	train-merror:0.11951	val-merror:0.257269
# [151]	train-merror:0.118867	val-merror:0.257269
# [152]	train-merror:0.118139	val-merror:0.253744
# [153]	train-merror:0.118053	val-merror:0.254626
# [154]	train-merror:0.117239	val-merror:0.255507
# [155]	train-merror:0.116339	val-merror:0.254626
# [156]	train-merror:0.116125	val-merror:0.256388
# [157]	train-merror:0.115653	val-merror:0.25815
# [158]	train-merror:0.11531	val-merror:0.25815
# [159]	train-merror:0.114668	val-merror:0.257269
# [160]	train-merror:0.113982	val-merror:0.257269
# [161]	train-merror:0.113554	val-merror:0.259031
# [162]	train-merror:0.112654	val-merror:0.259031
# [163]	train-merror:0.111925	val-merror:0.259031
# [164]	train-merror:0.11154	val-merror:0.259031
# [165]	train-merror:0.111111	val-merror:0.259031
# [166]	train-merror:0.110468	val-merror:0.257269
# [167]	train-merror:0.109997	val-merror:0.257269
# [168]	train-merror:0.109568	val-merror:0.257269
# [169]	train-merror:0.108926	val-merror:0.259912
# [170]	train-merror:0.108497	val-merror:0.259031
# [171]	train-merror:0.10764	val-merror:0.259912
# [172]	train-merror:0.107169	val-merror:0.25815
# [173]	train-merror:0.106783	val-merror:0.256388
# [174]	train-merror:0.106055	val-merror:0.259912
# [175]	train-merror:0.105969	val-merror:0.259912
# [176]	train-merror:0.105155	val-merror:0.260793
# [177]	train-merror:0.104684	val-merror:0.259912
# [178]	train-merror:0.103569	val-merror:0.259031
# [179]	train-merror:0.103184	val-merror:0.259031
# [180]	train-merror:0.102241	val-merror:0.259031
# [181]	train-merror:0.102155	val-merror:0.257269
# [182]	train-merror:0.101513	val-merror:0.259031
# [183]	train-merror:0.10147	val-merror:0.256388
# [184]	train-merror:0.100784	val-merror:0.257269
# [185]	train-merror:0.099713	val-merror:0.256388
# [186]	train-merror:0.099242	val-merror:0.252863
# [187]	train-merror:0.098813	val-merror:0.254626
# [188]	train-merror:0.09817	val-merror:0.257269
# [189]	train-merror:0.097528	val-merror:0.256388
# [190]	train-merror:0.096885	val-merror:0.257269
# [191]	train-merror:0.096242	val-merror:0.257269
# [192]	train-merror:0.095814	val-merror:0.252863
# [193]	train-merror:0.095171	val-merror:0.252863
# [194]	train-merror:0.094742	val-merror:0.251982
# [195]	train-merror:0.093971	val-merror:0.254626
# [196]	train-merror:0.093114	val-merror:0.251982
# [197]	train-merror:0.092943	val-merror:0.254626
# [198]	train-merror:0.092043	val-merror:0.252863
# [199]	train-merror:0.091786	val-merror:0.251982
# [200]	train-merror:0.090971	val-merror:0.25022
# [201]	train-merror:0.090629	val-merror:0.25022
# [202]	train-merror:0.090157	val-merror:0.251101
# [203]	train-merror:0.089472	val-merror:0.251982
# [204]	train-merror:0.089343	val-merror:0.254626
# [205]	train-merror:0.088315	val-merror:0.252863
# [206]	train-merror:0.087501	val-merror:0.252863
# [207]	train-merror:0.086815	val-merror:0.253744
# [208]	train-merror:0.086772	val-merror:0.255507
# [209]	train-merror:0.086001	val-merror:0.255507
# [210]	train-merror:0.085015	val-merror:0.257269
# [211]	train-merror:0.084458	val-merror:0.254626
# [212]	train-merror:0.084158	val-merror:0.254626
# [213]	train-merror:0.083344	val-merror:0.256388
# [214]	train-merror:0.083301	val-merror:0.256388
# [215]	train-merror:0.082658	val-merror:0.251982
# [216]	train-merror:0.082487	val-merror:0.254626
# [217]	train-merror:0.081973	val-merror:0.254626
# [218]	train-merror:0.08073	val-merror:0.253744
# [219]	train-merror:0.08043	val-merror:0.253744
# [220]	train-merror:0.079702	val-merror:0.254626
# [221]	train-merror:0.07893	val-merror:0.252863
# [222]	train-merror:0.07863	val-merror:0.251982
# [223]	train-merror:0.078159	val-merror:0.253744
# [224]	train-merror:0.077988	val-merror:0.254626
# [225]	train-merror:0.077131	val-merror:0.254626
# [226]	train-merror:0.076745	val-merror:0.252863
# [227]	train-merror:0.076702	val-merror:0.254626
# [228]	train-merror:0.075888	val-merror:0.254626
# [229]	train-merror:0.075117	val-merror:0.255507
# [230]	train-merror:0.074603	val-merror:0.251982
# [231]	train-merror:0.074303	val-merror:0.252863
# [232]	train-merror:0.074003	val-merror:0.254626
# [233]	train-merror:0.072974	val-merror:0.252863
# [234]	train-merror:0.072289	val-merror:0.25022
# [235]	train-merror:0.071432	val-merror:0.249339
# [236]	train-merror:0.071217	val-merror:0.252863
# [237]	train-merror:0.07036	val-merror:0.251101
# [238]	train-merror:0.07006	val-merror:0.249339
# [239]	train-merror:0.069075	val-merror:0.248458
# [240]	train-merror:0.068861	val-merror:0.251101
# [241]	train-merror:0.068132	val-merror:0.249339
# [242]	train-merror:0.068089	val-merror:0.247577
# [243]	train-merror:0.067489	val-merror:0.25022
# [244]	train-merror:0.067275	val-merror:0.251982
# [245]	train-merror:0.066761	val-merror:0.25022
# [246]	train-merror:0.066375	val-merror:0.25022
# [247]	train-merror:0.065818	val-merror:0.248458
# [248]	train-merror:0.065133	val-merror:0.251101
# [249]	train-merror:0.064533	val-merror:0.251101
# [250]	train-merror:0.06389	val-merror:0.252863
# [251]	train-merror:0.063161	val-merror:0.251101
# [252]	train-merror:0.063161	val-merror:0.251982
# [253]	train-merror:0.063161	val-merror:0.251982
# [254]	train-merror:0.062176	val-merror:0.25022
# [255]	train-merror:0.061662	val-merror:0.251101
# [256]	train-merror:0.060976	val-merror:0.251982
# [257]	train-merror:0.060548	val-merror:0.251101
# [258]	train-merror:0.060162	val-merror:0.25022
# [259]	train-merror:0.060162	val-merror:0.249339
# [260]	train-merror:0.059219	val-merror:0.25022
# [261]	train-merror:0.058534	val-merror:0.25022
# [262]	train-merror:0.058105	val-merror:0.251101
# [263]	train-merror:0.057548	val-merror:0.251101
# [264]	train-merror:0.057162	val-merror:0.251982
# [265]	train-merror:0.056691	val-merror:0.251982
# [266]	train-merror:0.05622	val-merror:0.251982
# [267]	train-merror:0.055748	val-merror:0.251982
# [268]	train-merror:0.055577	val-merror:0.25022
# [269]	train-merror:0.055406	val-merror:0.251101
# [270]	train-merror:0.054934	val-merror:0.251101
# [271]	train-merror:0.054677	val-merror:0.249339
# [272]	train-merror:0.054206	val-merror:0.247577
# [273]	train-merror:0.053777	val-merror:0.248458
# [274]	train-merror:0.052877	val-merror:0.249339
# [275]	train-merror:0.052749	val-merror:0.25022
# [276]	train-merror:0.052492	val-merror:0.248458
# [277]	train-merror:0.051635	val-merror:0.249339
# [278]	train-merror:0.051335	val-merror:0.248458
# [279]	train-merror:0.051163	val-merror:0.245815
# [280]	train-merror:0.050821	val-merror:0.248458
# [281]	train-merror:0.050178	val-merror:0.247577
# [282]	train-merror:0.049878	val-merror:0.249339
# [283]	train-merror:0.049107	val-merror:0.249339
# [284]	train-merror:0.048635	val-merror:0.251101
# [285]	train-merror:0.048164	val-merror:0.251982
# [286]	train-merror:0.047821	val-merror:0.251101
# [287]	train-merror:0.047178	val-merror:0.251982
# [288]	train-merror:0.046793	val-merror:0.251982
# [289]	train-merror:0.046536	val-merror:0.25022
# [290]	train-merror:0.04615	val-merror:0.248458
# [291]	train-merror:0.045721	val-merror:0.25022
# [292]	train-merror:0.045636	val-merror:0.251101
# [293]	train-merror:0.04525	val-merror:0.251982
# [294]	train-merror:0.044907	val-merror:0.249339
# [295]	train-merror:0.044136	val-merror:0.251982
# [296]	train-merror:0.044007	val-merror:0.251101
# [297]	train-merror:0.043836	val-merror:0.249339
# [298]	train-merror:0.043665	val-merror:0.25022
# [299]	train-merror:0.042765	val-merror:0.249339
# [300]	train-merror:0.042422	val-merror:0.25022
# [301]	train-merror:0.042293	val-merror:0.249339
# [302]	train-merror:0.041993	val-merror:0.248458
# [303]	train-merror:0.041436	val-merror:0.249339
# [304]	train-merror:0.040965	val-merror:0.249339
# [305]	train-merror:0.040494	val-merror:0.249339
# [306]	train-merror:0.040194	val-merror:0.25022
# [307]	train-merror:0.039594	val-merror:0.249339
# [308]	train-merror:0.039422	val-merror:0.248458
# [309]	train-merror:0.038865	val-merror:0.249339
# [310]	train-merror:0.038223	val-merror:0.248458
# [311]	train-merror:0.037837	val-merror:0.249339
# [312]	train-merror:0.037408	val-merror:0.248458
# [313]	train-merror:0.037066	val-merror:0.249339
# [314]	train-merror:0.036766	val-merror:0.247577
# [315]	train-merror:0.035866	val-merror:0.247577
# [316]	train-merror:0.035694	val-merror:0.248458
# [317]	train-merror:0.035137	val-merror:0.249339
# [318]	train-merror:0.034795	val-merror:0.249339
# [319]	train-merror:0.034709	val-merror:0.251101
# [320]	train-merror:0.034152	val-merror:0.248458
# [321]	train-merror:0.033552	val-merror:0.248458
# [322]	train-merror:0.033252	val-merror:0.25022
# [323]	train-merror:0.032823	val-merror:0.248458
# [324]	train-merror:0.032523	val-merror:0.249339
# [325]	train-merror:0.032009	val-merror:0.248458
# [326]	train-merror:0.031881	val-merror:0.249339
# [327]	train-merror:0.031624	val-merror:0.248458
# [328]	train-merror:0.031495	val-merror:0.251101
# [329]	train-merror:0.031324	val-merror:0.25022
# [330]	train-merror:0.031238	val-merror:0.251101
# [331]	train-merror:0.030467	val-merror:0.251982
# [332]	train-merror:0.030038	val-merror:0.251101
# [333]	train-merror:0.029952	val-merror:0.25022
# [334]	train-merror:0.029652	val-merror:0.251101
# [335]	train-merror:0.029267	val-merror:0.253744
# [336]	train-merror:0.02931	val-merror:0.252863
# [337]	train-merror:0.029267	val-merror:0.251101
# [338]	train-merror:0.028924	val-merror:0.254626
# [339]	train-merror:0.028581	val-merror:0.253744
# [340]	train-merror:0.028324	val-merror:0.254626
# [341]	train-merror:0.027853	val-merror:0.256388
# [342]	train-merror:0.027639	val-merror:0.256388
# [343]	train-merror:0.027596	val-merror:0.254626
# [344]	train-merror:0.027124	val-merror:0.252863
# [345]	train-merror:0.026739	val-merror:0.25022
# [346]	train-merror:0.026396	val-merror:0.252863
# [347]	train-merror:0.025924	val-merror:0.251101
# [348]	train-merror:0.025496	val-merror:0.251982
# [349]	train-merror:0.025325	val-merror:0.252863
# [350]	train-merror:0.025153	val-merror:0.253744
# [351]	train-merror:0.024639	val-merror:0.254626
# [352]	train-merror:0.024596	val-merror:0.254626
# [353]	train-merror:0.024168	val-merror:0.253744
# [354]	train-merror:0.023825	val-merror:0.252863
# [355]	train-merror:0.023696	val-merror:0.251101
# [356]	train-merror:0.023653	val-merror:0.251982
# [357]	train-merror:0.023268	val-merror:0.251101
# [358]	train-merror:0.022839	val-merror:0.252863
# [359]	train-merror:0.022582	val-merror:0.252863
# [360]	train-merror:0.022368	val-merror:0.251982
# [361]	train-merror:0.022197	val-merror:0.253744
# [362]	train-merror:0.022025	val-merror:0.251982
# [363]	train-merror:0.021554	val-merror:0.252863
# [364]	train-merror:0.021254	val-merror:0.253744
# [365]	train-merror:0.02104	val-merror:0.252863
# [366]	train-merror:0.020482	val-merror:0.252863
# [367]	train-merror:0.02044	val-merror:0.254626
# [368]	train-merror:0.020311	val-merror:0.251982
# [369]	train-merror:0.01984	val-merror:0.251101
# [370]	train-merror:0.019797	val-merror:0.25022
# [371]	train-merror:0.01954	val-merror:0.25022
# [372]	train-merror:0.019111	val-merror:0.251101
# [373]	train-merror:0.018983	val-merror:0.25022
# [374]	train-merror:0.018897	val-merror:0.251982
# [375]	train-merror:0.018768	val-merror:0.251101
# [376]	train-merror:0.018554	val-merror:0.251982
# [377]	train-merror:0.018254	val-merror:0.251982
# [378]	train-merror:0.018211	val-merror:0.251982
# [379]	train-merror:0.01804	val-merror:0.251101
# Stopping. Best iteration:
# [279]	train-merror:0.051163	val-merror:0.245815
#
# 279
# array([1., 0., 1., ..., 2., 2., 2.], dtype=float32)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_dataset['fix_result'], preds)
# Out:
# 0.7515418502202643
