# %% [markdown]
# # 结论
#
# + 该方案可以直接适用于新的数据源，可以在更大的数据结果里进行尝试
# + 77%的成果率，数据非常稳定

# %%
import pymysql.cursors
import pandas as pd
from sklearn import preprocessing
import numpy as np
import re
import datetime
from sklearn.metrics import accuracy_score
import xgboost as xgb
from sklearn.svm import SVC
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, GridSearchCV

# %% [markdown]
# # 训练

# %% [markdown]
# ## 获取全量的竞彩比赛列表

# %%
connection = pymysql.connect(host='localhost', user='root', password='breadt@2019', db='breadt-football-ml', charset='utf8mb4', cursorclass=pymysql.cursors.DictCursor)
with connection.cursor() as cursor:
    sql = 'select * from `breadt_football_game_list`;'
    cursor.execute(sql)
    rows = cursor.fetchall()
    
    train_game_list_df = pd.DataFrame(rows)
    
    connection.close()

train_game_list_df['source'] = 'jc'

# %% [markdown]
# ## 获取全量的胜负彩比赛列表

# %%
connection = pymysql.connect(host='localhost', user='root', password='breadt@2019', db='breadt-football-ml', charset='utf8mb4', cursorclass=pymysql.cursors.DictCursor)
with connection.cursor() as cursor:
    sql = 'select * from `breadt_lottery_info`;'
    cursor.execute(sql)
    rows = cursor.fetchall()
    
    train_lottery_game_list_df = pd.DataFrame(rows)
    
    connection.close()

train_lottery_game_list_df['source'] = 'lottery'

# %% [markdown]
# ## 合并竞彩比赛列表和胜负彩比赛列表

# %%
tmp = train_lottery_game_list_df.drop(['issue'], axis=1)
df = pd.concat([train_game_list_df, tmp])
df = df[['matchid', 'game', 'home_team', 'visit_team', 'gs', 'gd', 'gn', 'time', 'result', 'win_bet_return', 'draw_bet_return', 'lose_bet_return', 'source']]
df = df.drop_duplicates(subset=['matchid'])

# %%
# 对team做encode 这个encoder后面预测的时候还会用到
teams = list(set(df['home_team'].values) | set(df['visit_team'].values))
team_encoder = preprocessing.LabelEncoder()
team_encoder.fit(teams)
# Out:
# LabelEncoder()

# %%
def encode_team(df):
    df['home_team_encoder'] = team_encoder.transform(df['home_team'])
    df['visit_team_encoder'] = team_encoder.transform(df['visit_team'])
    return df

# %%
# 比赛名称encode
games = list(set(df['game'].values))
game_encoder = preprocessing.LabelEncoder()
game_encoder.fit(games)
# Out:
# LabelEncoder()

# %%
def encode_game(df):
    df['game_encoder'] = game_encoder.transform(df['game'])
    return df

# %%
df['year'] = df.apply(lambda row: row.time.year, axis=1)
df['month'] = df.apply(lambda row: row.time.month, axis=1)
df['day'] = df.apply(lambda row: row.time.day, axis=1)
df['fix_result'] = df.apply(lambda row: int(row.result) if row.result < 3 else 2, axis=1)

# %%
df = encode_team(df)
df = encode_game(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57053 entries, 0 to 12650
# Data columns (total 20 columns):
# matchid               57053 non-null int64
# game                  57053 non-null object
# home_team             57053 non-null object
# visit_team            57053 non-null object
# gs                    57053 non-null int64
# gd                    57053 non-null int64
# gn                    57053 non-null int64
# time                  57053 non-null datetime64[ns]
# result                57053 non-null int64
# win_bet_return        57053 non-null float64
# draw_bet_return       57053 non-null float64
# lose_bet_return       57053 non-null float64
# source                57053 non-null object
# year                  57053 non-null int64
# month                 57053 non-null int64
# day                   57053 non-null int64
# fix_result            57053 non-null int64
# home_team_encoder     57053 non-null int64
# visit_team_encoder    57053 non-null int64
# game_encoder          57053 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(12), object(4)
# memory usage: 9.1+ MB

# %% [markdown]
# ## 获取赔率信息

# %%
connection = pymysql.connect(host='localhost', user='root', password='breadt@2019', db='breadt-football-ml', charset='utf8mb4', cursorclass=pymysql.cursors.DictCursor)
with connection.cursor() as cursor:
    sql = 'select * from `breadt_match_odd_info`;'
    cursor.execute(sql)
    rows = cursor.fetchall()
    
    train_match_odd_df = pd.DataFrame(rows)
    
    connection.close()

# %%
train_match_odd_df['avg_win_odd_change'] = (train_match_odd_df['avg_new_win_odd'] - train_match_odd_df['avg_init_win_odd'])/train_match_odd_df['avg_init_win_odd']
train_match_odd_df['avg_draw_odd_change'] = (train_match_odd_df['avg_new_draw_odd'] - train_match_odd_df['avg_init_draw_odd'])/train_match_odd_df['avg_init_draw_odd']
train_match_odd_df['avg_lose_odd_change'] = (train_match_odd_df['avg_new_lose_odd'] - train_match_odd_df['avg_init_lose_odd'])/train_match_odd_df['avg_init_lose_odd']

# %% [markdown]
# ## 合并训练数据

# %%
train_dataset_df = pd.merge(df, train_match_odd_df, on='matchid', how='left')
train_dataset_df = train_dataset_df.dropna()
train_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42622 entries, 0 to 56503
# Data columns (total 69 columns):
# matchid                42622 non-null int64
# game                   42622 non-null object
# home_team              42622 non-null object
# visit_team             42622 non-null object
# gs                     42622 non-null int64
# gd                     42622 non-null int64
# gn                     42622 non-null int64
# time                   42622 non-null datetime64[ns]
# result                 42622 non-null int64
# win_bet_return         42622 non-null float64
# draw_bet_return        42622 non-null float64
# lose_bet_return        42622 non-null float64
# source                 42622 non-null object
# year                   42622 non-null int64
# month                  42622 non-null int64
# day                    42622 non-null int64
# fix_result             42622 non-null int64
# home_team_encoder      42622 non-null int64
# visit_team_encoder     42622 non-null int64
# game_encoder           42622 non-null int64
# avg_init_draw_odd      42622 non-null float64
# avg_init_lose_odd      42622 non-null float64
# avg_init_win_odd       42622 non-null float64
# avg_new_draw_kelly     42622 non-null float64
# avg_new_draw_odd       42622 non-null float64
# avg_new_draw_rate      42622 non-null float64
# avg_new_lose_kelly     42622 non-null float64
# avg_new_lose_odd       42622 non-null float64
# avg_new_lose_rate      42622 non-null float64
# avg_new_win_kelly      42622 non-null float64
# avg_new_win_odd        42622 non-null float64
# avg_new_win_rate       42622 non-null float64
# avg_pay_rate           42622 non-null float64
# dispersion_draw        42622 non-null float64
# dispersion_lose        42622 non-null float64
# dispersion_win         42622 non-null float64
# id                     42622 non-null float64
# max_init_draw_odd      42622 non-null float64
# max_init_lose_odd      42622 non-null float64
# max_init_win_odd       42622 non-null float64
# max_new_draw_kelly     42622 non-null float64
# max_new_draw_odd       42622 non-null float64
# max_new_draw_rate      42622 non-null float64
# max_new_lose_kelly     42622 non-null float64
# max_new_lose_odd       42622 non-null float64
# max_new_lose_rate      42622 non-null float64
# max_new_win_kelly      42622 non-null float64
# max_new_win_odd        42622 non-null float64
# max_new_win_rate       42622 non-null float64
# max_pay_rate           42622 non-null float64
# min_init_draw_odd      42622 non-null float64
# min_init_lose_odd      42622 non-null float64
# min_init_win_odd       42622 non-null float64
# min_new_draw_kelly     42622 non-null float64
# min_new_draw_odd       42622 non-null float64
# min_new_draw_rate      42622 non-null float64
# min_new_lose_kelly     42622 non-null float64
# min_new_lose_odd       42622 non-null float64
# min_new_lose_rate      42622 non-null float64
# min_new_win_kelly      42622 non-null float64
# min_new_win_odd        42622 non-null float64
# min_new_win_rate       42622 non-null float64
# min_pay_rate           42622 non-null float64
# std_draw               42622 non-null float64
# std_lose               42622 non-null float64
# std_win                42622 non-null float64
# avg_win_odd_change     42622 non-null float64
# avg_draw_odd_change    42622 non-null float64
# avg_lose_odd_change    42622 non-null float64
# dtypes: datetime64[ns](1), float64(52), int64(12), object(4)
# memory usage: 22.8+ MB

# %%
train_dataset_df.columns.values
# Out:
# array(['matchid', 'game', 'home_team', 'visit_team', 'gs', 'gd', 'gn',
#        'time', 'result', 'win_bet_return', 'draw_bet_return',
#        'lose_bet_return', 'source', 'year', 'month', 'day', 'fix_result',
#        'home_team_encoder', 'visit_team_encoder', 'game_encoder',
#        'avg_init_draw_odd', 'avg_init_lose_odd', 'avg_init_win_odd',
#        'avg_new_draw_kelly', 'avg_new_draw_odd', 'avg_new_draw_rate',
#        'avg_new_lose_kelly', 'avg_new_lose_odd', 'avg_new_lose_rate',
#        'avg_new_win_kelly', 'avg_new_win_odd', 'avg_new_win_rate',
#        'avg_pay_rate', 'dispersion_draw', 'dispersion_lose',
#        'dispersion_win', 'id', 'max_init_draw_odd', 'max_init_lose_odd',
#        'max_init_win_odd', 'max_new_draw_kelly', 'max_new_draw_odd',
#        'max_new_draw_rate', 'max_new_lose_kelly', 'max_new_lose_odd',
#        'max_new_lose_rate', 'max_new_win_kelly', 'max_new_win_odd',
#        'max_new_win_rate', 'max_pay_rate', 'min_init_draw_odd',
#        'min_init_lose_odd', 'min_init_win_odd', 'min_new_draw_kelly',
#        'min_new_draw_odd', 'min_new_draw_rate', 'min_new_lose_kelly',
#        'min_new_lose_odd', 'min_new_lose_rate', 'min_new_win_kelly',
#        'min_new_win_odd', 'min_new_win_rate', 'min_pay_rate', 'std_draw',
#        'std_lose', 'std_win', 'avg_win_odd_change', 'avg_draw_odd_change',
#        'avg_lose_odd_change'], dtype=object)

# %% [markdown]
# # xgb训练

# %%
x_columns = [
    'year', 'month',
    'home_team_encoder', 'visit_team_encoder', 
    'game_encoder',
    'avg_init_draw_odd','avg_init_lose_odd', 'avg_init_win_odd', 
    
    'avg_new_draw_kelly',
    'avg_new_draw_odd', 
    'avg_new_draw_rate', 
    'avg_new_lose_kelly',
    'avg_new_lose_odd', 
    'avg_new_lose_rate', 'avg_new_win_kelly',
    'avg_new_win_odd', 
    'avg_new_win_rate', 'avg_pay_rate',
    'dispersion_draw', 'dispersion_lose', 'dispersion_win', 
    'max_init_draw_odd', 'max_init_lose_odd', 'max_init_win_odd',
    'max_new_draw_kelly', 'max_new_draw_odd', 'max_new_draw_rate',
    'max_new_lose_kelly', 'max_new_lose_odd', 'max_new_lose_rate',
    'max_new_win_kelly', 'max_new_win_odd', 'max_new_win_rate',
    'max_pay_rate', 'min_init_draw_odd', 'min_init_lose_odd',
    'min_init_win_odd', 'min_new_draw_kelly', 'min_new_draw_odd',
    'min_new_draw_rate', 'min_new_lose_kelly', 'min_new_lose_odd',
    'min_new_lose_rate', 'min_new_win_kelly', 'min_new_win_odd',
    'min_new_win_rate', 'min_pay_rate', 'std_draw', 'std_lose',
    'std_win', 'avg_win_odd_change', 'avg_draw_odd_change',
    'avg_lose_odd_change'
]

# %%
params={
    'booster':'gbtree',
    # 这里手写数字是0-9，是一个多类的问题，因此采用了multisoft多分类器，
    'objective': 'multi:softmax', 
#     'objective': 'multi:softprob',
    'num_class':3, # 类数，与 multisoftmax 并用
    'gamma':0.01,  # 在树的叶子节点下一个分区的最小损失，越大算法模型越保守 。[0:]
    'max_depth':8, # 构建树的深度 [1:]
    #'lambda':450,  # L2 正则项权重
    'subsample':0.7, # 采样训练数据，设置为0.5，随机选择一般的数据实例 (0:1]
    'colsample_bytree':0.7, # 构建树树时的采样比率 (0:1]
    #'min_child_weight':12, # 节点的最少特征数
    'silent':1 ,
    'eta': 0.01, # 如同学习率
    'seed':2018,
    'nthread':4,# cpu 线程数,根据自己U的个数适当调整
}

t = train_dataset_df

scaler = StandardScaler()
scaler.fit(t[x_columns])

train_dataset = t[t['year'] < 2019]
test_dataset = t[t['year'] == 2019]

valid_dataset = test_dataset[test_dataset['month'] < 3]
test_dataset = test_dataset[test_dataset['month'] >= 3]

xgtrain = xgb.DMatrix(scaler.transform(train_dataset[x_columns]), label=train_dataset['fix_result'])
xgtest = xgb.DMatrix(scaler.transform(test_dataset[x_columns]), label=test_dataset['fix_result'])
xgvalid = xgb.DMatrix(scaler.transform(valid_dataset[x_columns]), label=valid_dataset['fix_result'])

watchlist = [(xgtrain, 'train'),(xgvalid, 'val')]

num_rounds = 10000
stop_rounds = 300
# Out:
# /home/leewind/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:30: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
# /home/leewind/.local/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/leewind/.local/lib/python3.6/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:31: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
# /home/leewind/.local/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/leewind/.local/lib/python3.6/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:32: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
# /home/leewind/.local/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/leewind/.local/lib/python3.6/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %% [markdown]
# ## 单场正确性预测

# %%
params['objective'] = 'multi:softmax'
model = xgb.train(params, xgtrain, num_rounds, watchlist,early_stopping_rounds=stop_rounds)
print(model.best_iteration)
# Out:
# [0]	train-merror:0.46154	val-merror:0.503394
# Multiple eval metrics have been passed: 'val-merror' will be used for early stopping.
#
# Will train until val-merror hasn't improved in 300 rounds.
# [1]	train-merror:0.452661	val-merror:0.495475
# [2]	train-merror:0.45182	val-merror:0.496606
# [3]	train-merror:0.452216	val-merror:0.49095
# [4]	train-merror:0.451326	val-merror:0.487557
# [5]	train-merror:0.452216	val-merror:0.492081
# [6]	train-merror:0.453502	val-merror:0.492081
# [7]	train-merror:0.452043	val-merror:0.487557
# [8]	train-merror:0.451721	val-merror:0.495475
# [9]	train-merror:0.453106	val-merror:0.492081
# [10]	train-merror:0.451796	val-merror:0.492081
# [11]	train-merror:0.451153	val-merror:0.49095
# [12]	train-merror:0.451375	val-merror:0.49095
# [13]	train-merror:0.451326	val-merror:0.485294
# [14]	train-merror:0.451672	val-merror:0.483032
# [15]	train-merror:0.452364	val-merror:0.486425
# [16]	train-merror:0.451771	val-merror:0.485294
# [17]	train-merror:0.451573	val-merror:0.484163
# [18]	train-merror:0.452191	val-merror:0.485294
# [19]	train-merror:0.452538	val-merror:0.488688
# [20]	train-merror:0.452266	val-merror:0.49095
# [21]	train-merror:0.451622	val-merror:0.492081
# [22]	train-merror:0.45229	val-merror:0.493213
# [23]	train-merror:0.452018	val-merror:0.49095
# [24]	train-merror:0.451499	val-merror:0.492081
# [25]	train-merror:0.452142	val-merror:0.493213
# [26]	train-merror:0.451573	val-merror:0.487557
# [27]	train-merror:0.451895	val-merror:0.486425
# [28]	train-merror:0.451548	val-merror:0.488688
# [29]	train-merror:0.451177	val-merror:0.488688
# [30]	train-merror:0.451474	val-merror:0.488688
# [31]	train-merror:0.451276	val-merror:0.488688
# [32]	train-merror:0.450856	val-merror:0.488688
# [33]	train-merror:0.451103	val-merror:0.488688
# [34]	train-merror:0.450905	val-merror:0.488688
# [35]	train-merror:0.45093	val-merror:0.486425
# [36]	train-merror:0.451004	val-merror:0.486425
# [37]	train-merror:0.451153	val-merror:0.488688
# [38]	train-merror:0.451301	val-merror:0.488688
# [39]	train-merror:0.451078	val-merror:0.488688
# [40]	train-merror:0.451301	val-merror:0.486425
# [41]	train-merror:0.451375	val-merror:0.486425
# [42]	train-merror:0.450955	val-merror:0.488688
# [43]	train-merror:0.450633	val-merror:0.489819
# [44]	train-merror:0.451103	val-merror:0.49095
# [45]	train-merror:0.450683	val-merror:0.492081
# [46]	train-merror:0.450658	val-merror:0.495475
# [47]	train-merror:0.450683	val-merror:0.49095
# [48]	train-merror:0.450509	val-merror:0.492081
# [49]	train-merror:0.450411	val-merror:0.493213
# [50]	train-merror:0.450163	val-merror:0.492081
# [51]	train-merror:0.450213	val-merror:0.493213
# [52]	train-merror:0.450064	val-merror:0.492081
# [53]	train-merror:0.449866	val-merror:0.489819
# [54]	train-merror:0.450163	val-merror:0.49095
# [55]	train-merror:0.450237	val-merror:0.493213
# [56]	train-merror:0.450213	val-merror:0.492081
# [57]	train-merror:0.450411	val-merror:0.492081
# [58]	train-merror:0.450287	val-merror:0.492081
# [59]	train-merror:0.450287	val-merror:0.489819
# [60]	train-merror:0.450089	val-merror:0.489819
# [61]	train-merror:0.449792	val-merror:0.492081
# [62]	train-merror:0.449817	val-merror:0.49095
# [63]	train-merror:0.450064	val-merror:0.49095
# [64]	train-merror:0.449495	val-merror:0.49095
# [65]	train-merror:0.449347	val-merror:0.49095
# [66]	train-merror:0.449322	val-merror:0.49095
# [67]	train-merror:0.449075	val-merror:0.492081
# [68]	train-merror:0.449026	val-merror:0.492081
# [69]	train-merror:0.449075	val-merror:0.489819
# [70]	train-merror:0.448655	val-merror:0.488688
# [71]	train-merror:0.448556	val-merror:0.489819
# [72]	train-merror:0.448605	val-merror:0.492081
# [73]	train-merror:0.44816	val-merror:0.493213
# [74]	train-merror:0.448036	val-merror:0.493213
# [75]	train-merror:0.448259	val-merror:0.493213
# [76]	train-merror:0.44816	val-merror:0.493213
# [77]	train-merror:0.448185	val-merror:0.494344
# [78]	train-merror:0.448234	val-merror:0.494344
# [79]	train-merror:0.448259	val-merror:0.494344
# [80]	train-merror:0.448185	val-merror:0.494344
# [81]	train-merror:0.44816	val-merror:0.494344
# [82]	train-merror:0.447913	val-merror:0.492081
# [83]	train-merror:0.447789	val-merror:0.492081
# [84]	train-merror:0.447888	val-merror:0.49095
# [85]	train-merror:0.447863	val-merror:0.49095
# [86]	train-merror:0.447764	val-merror:0.49095
# [87]	train-merror:0.447838	val-merror:0.492081
# [88]	train-merror:0.447418	val-merror:0.49095
# [89]	train-merror:0.446898	val-merror:0.492081
# [90]	train-merror:0.447047	val-merror:0.492081
# [91]	train-merror:0.446948	val-merror:0.492081
# [92]	train-merror:0.447022	val-merror:0.492081
# [93]	train-merror:0.446923	val-merror:0.492081
# [94]	train-merror:0.446577	val-merror:0.49095
# [95]	train-merror:0.446676	val-merror:0.493213
# [96]	train-merror:0.446379	val-merror:0.49095
# [97]	train-merror:0.446429	val-merror:0.489819
# [98]	train-merror:0.446404	val-merror:0.492081
# [99]	train-merror:0.44633	val-merror:0.492081
# [100]	train-merror:0.446033	val-merror:0.493213
# [101]	train-merror:0.445959	val-merror:0.494344
# [102]	train-merror:0.445983	val-merror:0.493213
# [103]	train-merror:0.445934	val-merror:0.494344
# [104]	train-merror:0.446231	val-merror:0.492081
# [105]	train-merror:0.446033	val-merror:0.49095
# [106]	train-merror:0.446132	val-merror:0.49095
# [107]	train-merror:0.445983	val-merror:0.49095
# [108]	train-merror:0.446058	val-merror:0.492081
# [109]	train-merror:0.44581	val-merror:0.492081
# [110]	train-merror:0.445761	val-merror:0.493213
# [111]	train-merror:0.445662	val-merror:0.493213
# [112]	train-merror:0.445687	val-merror:0.493213
# [113]	train-merror:0.445662	val-merror:0.49095
# [114]	train-merror:0.445711	val-merror:0.49095
# [115]	train-merror:0.445786	val-merror:0.49095
# [116]	train-merror:0.445711	val-merror:0.49095
# [117]	train-merror:0.445489	val-merror:0.49095
# [118]	train-merror:0.445192	val-merror:0.49095
# [119]	train-merror:0.445266	val-merror:0.49095
# [120]	train-merror:0.444895	val-merror:0.49095
# [121]	train-merror:0.444796	val-merror:0.489819
# [122]	train-merror:0.444673	val-merror:0.489819
# [123]	train-merror:0.444648	val-merror:0.489819
# [124]	train-merror:0.444499	val-merror:0.489819
# [125]	train-merror:0.444524	val-merror:0.489819
# [126]	train-merror:0.444326	val-merror:0.489819
# [127]	train-merror:0.444351	val-merror:0.489819
# [128]	train-merror:0.4444	val-merror:0.489819
# [129]	train-merror:0.444499	val-merror:0.49095
# [130]	train-merror:0.444425	val-merror:0.49095
# [131]	train-merror:0.444351	val-merror:0.49095
# [132]	train-merror:0.444104	val-merror:0.492081
# [133]	train-merror:0.44398	val-merror:0.492081
# [134]	train-merror:0.444128	val-merror:0.493213
# [135]	train-merror:0.443955	val-merror:0.494344
# [136]	train-merror:0.444005	val-merror:0.495475
# [137]	train-merror:0.444029	val-merror:0.492081
# [138]	train-merror:0.443757	val-merror:0.492081
# [139]	train-merror:0.443757	val-merror:0.492081
# [140]	train-merror:0.443609	val-merror:0.492081
# [141]	train-merror:0.443609	val-merror:0.492081
# [142]	train-merror:0.443634	val-merror:0.492081
# [143]	train-merror:0.443807	val-merror:0.489819
# [144]	train-merror:0.44356	val-merror:0.494344
# [145]	train-merror:0.443535	val-merror:0.492081
# [146]	train-merror:0.443485	val-merror:0.49095
# [147]	train-merror:0.443189	val-merror:0.49095
# [148]	train-merror:0.44304	val-merror:0.49095
# [149]	train-merror:0.443139	val-merror:0.489819
# [150]	train-merror:0.443164	val-merror:0.49095
# [151]	train-merror:0.442966	val-merror:0.492081
# [152]	train-merror:0.44304	val-merror:0.493213
# [153]	train-merror:0.443065	val-merror:0.493213
# [154]	train-merror:0.442966	val-merror:0.492081
# [155]	train-merror:0.442966	val-merror:0.49095
# [156]	train-merror:0.442768	val-merror:0.49095
# [157]	train-merror:0.442719	val-merror:0.492081
# [158]	train-merror:0.442719	val-merror:0.492081
# [159]	train-merror:0.442521	val-merror:0.492081
# [160]	train-merror:0.442323	val-merror:0.492081
# [161]	train-merror:0.442001	val-merror:0.492081
# [162]	train-merror:0.441977	val-merror:0.49095
# [163]	train-merror:0.441853	val-merror:0.49095
# [164]	train-merror:0.442051	val-merror:0.492081
# [165]	train-merror:0.441878	val-merror:0.492081
# [166]	train-merror:0.441927	val-merror:0.492081
# [167]	train-merror:0.441606	val-merror:0.489819
# [168]	train-merror:0.44168	val-merror:0.492081
# [169]	train-merror:0.44168	val-merror:0.489819
# [170]	train-merror:0.441729	val-merror:0.49095
# [171]	train-merror:0.441507	val-merror:0.49095
# [172]	train-merror:0.441531	val-merror:0.492081
# [173]	train-merror:0.441433	val-merror:0.49095
# [174]	train-merror:0.441507	val-merror:0.489819
# [175]	train-merror:0.441581	val-merror:0.489819
# [176]	train-merror:0.441383	val-merror:0.488688
# [177]	train-merror:0.440839	val-merror:0.489819
# [178]	train-merror:0.44074	val-merror:0.489819
# [179]	train-merror:0.440493	val-merror:0.488688
# [180]	train-merror:0.440369	val-merror:0.489819
# [181]	train-merror:0.44027	val-merror:0.49095
# [182]	train-merror:0.440146	val-merror:0.49095
# [183]	train-merror:0.44027	val-merror:0.488688
# [184]	train-merror:0.440023	val-merror:0.49095
# [185]	train-merror:0.439899	val-merror:0.49095
# [186]	train-merror:0.4398	val-merror:0.49095
# [187]	train-merror:0.439874	val-merror:0.49095
# [188]	train-merror:0.440072	val-merror:0.49095
# [189]	train-merror:0.439924	val-merror:0.489819
# [190]	train-merror:0.439775	val-merror:0.49095
# [191]	train-merror:0.4398	val-merror:0.49095
# [192]	train-merror:0.4398	val-merror:0.49095
# [193]	train-merror:0.439676	val-merror:0.49095
# [194]	train-merror:0.439701	val-merror:0.488688
# [195]	train-merror:0.439578	val-merror:0.489819
# [196]	train-merror:0.439528	val-merror:0.489819
# [197]	train-merror:0.439256	val-merror:0.489819
# [198]	train-merror:0.439404	val-merror:0.489819
# [199]	train-merror:0.439404	val-merror:0.49095
# [200]	train-merror:0.439404	val-merror:0.49095
# [201]	train-merror:0.439157	val-merror:0.49095
# [202]	train-merror:0.439009	val-merror:0.492081
# [203]	train-merror:0.43886	val-merror:0.494344
# [204]	train-merror:0.438761	val-merror:0.493213
# [205]	train-merror:0.438786	val-merror:0.493213
# [206]	train-merror:0.438712	val-merror:0.493213
# [207]	train-merror:0.438539	val-merror:0.492081
# [208]	train-merror:0.43844	val-merror:0.493213
# [209]	train-merror:0.438242	val-merror:0.493213
# [210]	train-merror:0.438094	val-merror:0.494344
# [211]	train-merror:0.437945	val-merror:0.494344
# [212]	train-merror:0.437871	val-merror:0.494344
# [213]	train-merror:0.437747	val-merror:0.493213
# [214]	train-merror:0.437624	val-merror:0.493213
# [215]	train-merror:0.437673	val-merror:0.493213
# [216]	train-merror:0.437822	val-merror:0.494344
# [217]	train-merror:0.437772	val-merror:0.493213
# [218]	train-merror:0.437475	val-merror:0.493213
# [219]	train-merror:0.437599	val-merror:0.493213
# [220]	train-merror:0.437525	val-merror:0.493213
# [221]	train-merror:0.437154	val-merror:0.493213
# [222]	train-merror:0.437228	val-merror:0.492081
# [223]	train-merror:0.437055	val-merror:0.493213
# [224]	train-merror:0.436684	val-merror:0.493213
# [225]	train-merror:0.436709	val-merror:0.493213
# [226]	train-merror:0.436486	val-merror:0.493213
# [227]	train-merror:0.436659	val-merror:0.492081
# [228]	train-merror:0.436461	val-merror:0.492081
# [229]	train-merror:0.436362	val-merror:0.492081
# [230]	train-merror:0.436362	val-merror:0.493213
# [231]	train-merror:0.436486	val-merror:0.49095
# [232]	train-merror:0.436511	val-merror:0.49095
# [233]	train-merror:0.436412	val-merror:0.492081
# [234]	train-merror:0.436239	val-merror:0.492081
# [235]	train-merror:0.436115	val-merror:0.492081
# [236]	train-merror:0.43614	val-merror:0.492081
# [237]	train-merror:0.435991	val-merror:0.492081
# [238]	train-merror:0.435967	val-merror:0.489819
# [239]	train-merror:0.435694	val-merror:0.492081
# [240]	train-merror:0.435571	val-merror:0.492081
# [241]	train-merror:0.435818	val-merror:0.492081
# [242]	train-merror:0.435571	val-merror:0.492081
# [243]	train-merror:0.435373	val-merror:0.492081
# [244]	train-merror:0.435348	val-merror:0.492081
# [245]	train-merror:0.435348	val-merror:0.492081
# [246]	train-merror:0.435422	val-merror:0.492081
# [247]	train-merror:0.43515	val-merror:0.492081
# [248]	train-merror:0.435126	val-merror:0.49095
# [249]	train-merror:0.435101	val-merror:0.49095
# [250]	train-merror:0.434878	val-merror:0.49095
# [251]	train-merror:0.434854	val-merror:0.49095
# [252]	train-merror:0.434755	val-merror:0.49095
# [253]	train-merror:0.434532	val-merror:0.49095
# [254]	train-merror:0.434359	val-merror:0.49095
# [255]	train-merror:0.434334	val-merror:0.49095
# [256]	train-merror:0.434161	val-merror:0.49095
# [257]	train-merror:0.434136	val-merror:0.492081
# [258]	train-merror:0.43384	val-merror:0.493213
# [259]	train-merror:0.433765	val-merror:0.493213
# [260]	train-merror:0.433617	val-merror:0.492081
# [261]	train-merror:0.433617	val-merror:0.492081
# [262]	train-merror:0.433469	val-merror:0.493213
# [263]	train-merror:0.433271	val-merror:0.493213
# [264]	train-merror:0.43332	val-merror:0.493213
# [265]	train-merror:0.43337	val-merror:0.493213
# [266]	train-merror:0.433394	val-merror:0.493213
# [267]	train-merror:0.433122	val-merror:0.493213
# [268]	train-merror:0.433098	val-merror:0.494344
# [269]	train-merror:0.433246	val-merror:0.494344
# [270]	train-merror:0.433147	val-merror:0.494344
# [271]	train-merror:0.432999	val-merror:0.493213
# [272]	train-merror:0.432776	val-merror:0.493213
# [273]	train-merror:0.432751	val-merror:0.494344
# [274]	train-merror:0.432553	val-merror:0.493213
# [275]	train-merror:0.432405	val-merror:0.492081
# [276]	train-merror:0.432356	val-merror:0.493213
# [277]	train-merror:0.432356	val-merror:0.494344
# [278]	train-merror:0.432232	val-merror:0.494344
# [279]	train-merror:0.432158	val-merror:0.494344
# [280]	train-merror:0.432207	val-merror:0.494344
# [281]	train-merror:0.432182	val-merror:0.494344
# [282]	train-merror:0.432133	val-merror:0.495475
# [283]	train-merror:0.432133	val-merror:0.495475
# [284]	train-merror:0.431935	val-merror:0.495475
# [285]	train-merror:0.431713	val-merror:0.495475
# [286]	train-merror:0.431638	val-merror:0.495475
# [287]	train-merror:0.431539	val-merror:0.495475
# [288]	train-merror:0.431465	val-merror:0.495475
# [289]	train-merror:0.431292	val-merror:0.493213
# [290]	train-merror:0.431045	val-merror:0.495475
# [291]	train-merror:0.431094	val-merror:0.495475
# [292]	train-merror:0.431045	val-merror:0.495475
# [293]	train-merror:0.430896	val-merror:0.495475
# [294]	train-merror:0.430674	val-merror:0.494344
# [295]	train-merror:0.430674	val-merror:0.494344
# [296]	train-merror:0.430649	val-merror:0.493213
# [297]	train-merror:0.430476	val-merror:0.493213
# [298]	train-merror:0.430229	val-merror:0.493213
# [299]	train-merror:0.430031	val-merror:0.493213
# [300]	train-merror:0.430055	val-merror:0.493213
# [301]	train-merror:0.429882	val-merror:0.493213
# [302]	train-merror:0.43008	val-merror:0.493213
# [303]	train-merror:0.430006	val-merror:0.493213
# [304]	train-merror:0.429684	val-merror:0.493213
# [305]	train-merror:0.429487	val-merror:0.493213
# [306]	train-merror:0.429462	val-merror:0.493213
# [307]	train-merror:0.429338	val-merror:0.492081
# [308]	train-merror:0.429289	val-merror:0.492081
# [309]	train-merror:0.429116	val-merror:0.492081
# [310]	train-merror:0.428942	val-merror:0.49095
# [311]	train-merror:0.428794	val-merror:0.49095
# [312]	train-merror:0.428621	val-merror:0.492081
# [313]	train-merror:0.428522	val-merror:0.492081
# [314]	train-merror:0.428374	val-merror:0.492081
# Stopping. Best iteration:
# [14]	train-merror:0.451672	val-merror:0.483032
#
# 14

# %%
xgtest = xgb.DMatrix(scaler.transform(test_dataset[x_columns]), label=test_dataset['fix_result'])
preds_new_test = model.predict(xgtest, ntree_limit=model.best_iteration)
preds_new_test
# Out:
# /home/leewind/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   """Entry point for launching an IPython kernel.
# /home/leewind/.local/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/leewind/.local/lib/python3.6/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# array([0., 2., 2., ..., 2., 2., 0.], dtype=float32)

# %%
accuracy_score(test_dataset['fix_result'], preds_new_test)
# Out:
# 0.4908116385911179

# %% [markdown]
# ## 验证选2场的结果

# %%
params['objective'] = 'multi:softprob'
model = xgb.train(params, xgtrain, num_rounds, watchlist,early_stopping_rounds=stop_rounds)
print(model.best_iteration)
# Out:
# [0]	train-merror:0.46154	val-merror:0.503394
# Multiple eval metrics have been passed: 'val-merror' will be used for early stopping.
#
# Will train until val-merror hasn't improved in 300 rounds.
# [1]	train-merror:0.452661	val-merror:0.495475
# [2]	train-merror:0.45182	val-merror:0.496606
# [3]	train-merror:0.452216	val-merror:0.49095
# [4]	train-merror:0.451326	val-merror:0.487557
# [5]	train-merror:0.452216	val-merror:0.492081
# [6]	train-merror:0.453502	val-merror:0.492081
# [7]	train-merror:0.452043	val-merror:0.487557
# [8]	train-merror:0.451721	val-merror:0.495475
# [9]	train-merror:0.453106	val-merror:0.492081
# [10]	train-merror:0.451796	val-merror:0.492081
# [11]	train-merror:0.451153	val-merror:0.49095
# [12]	train-merror:0.451375	val-merror:0.49095
# [13]	train-merror:0.451326	val-merror:0.485294
# [14]	train-merror:0.451672	val-merror:0.483032
# [15]	train-merror:0.452364	val-merror:0.486425
# [16]	train-merror:0.451771	val-merror:0.485294
# [17]	train-merror:0.451573	val-merror:0.484163
# [18]	train-merror:0.452191	val-merror:0.485294
# [19]	train-merror:0.452538	val-merror:0.488688
# [20]	train-merror:0.452266	val-merror:0.49095
# [21]	train-merror:0.451622	val-merror:0.492081
# [22]	train-merror:0.45229	val-merror:0.493213
# [23]	train-merror:0.452018	val-merror:0.49095
# [24]	train-merror:0.451499	val-merror:0.492081
# [25]	train-merror:0.452142	val-merror:0.493213
# [26]	train-merror:0.451573	val-merror:0.487557
# [27]	train-merror:0.451895	val-merror:0.486425
# [28]	train-merror:0.451548	val-merror:0.488688
# [29]	train-merror:0.451177	val-merror:0.488688
# [30]	train-merror:0.451474	val-merror:0.488688
# [31]	train-merror:0.451276	val-merror:0.488688
# [32]	train-merror:0.450856	val-merror:0.488688
# [33]	train-merror:0.451103	val-merror:0.488688
# [34]	train-merror:0.450905	val-merror:0.488688
# [35]	train-merror:0.45093	val-merror:0.486425
# [36]	train-merror:0.451004	val-merror:0.486425
# [37]	train-merror:0.451153	val-merror:0.488688
# [38]	train-merror:0.451301	val-merror:0.488688
# [39]	train-merror:0.451078	val-merror:0.488688
# [40]	train-merror:0.451301	val-merror:0.486425
# [41]	train-merror:0.451375	val-merror:0.486425
# [42]	train-merror:0.450955	val-merror:0.488688
# [43]	train-merror:0.450633	val-merror:0.489819
# [44]	train-merror:0.451103	val-merror:0.49095
# [45]	train-merror:0.450683	val-merror:0.492081
# [46]	train-merror:0.450658	val-merror:0.495475
# [47]	train-merror:0.450683	val-merror:0.49095
# [48]	train-merror:0.450509	val-merror:0.492081
# [49]	train-merror:0.450411	val-merror:0.493213
# [50]	train-merror:0.450163	val-merror:0.492081
# [51]	train-merror:0.450213	val-merror:0.493213
# [52]	train-merror:0.450064	val-merror:0.492081
# [53]	train-merror:0.449866	val-merror:0.489819
# [54]	train-merror:0.450163	val-merror:0.49095
# [55]	train-merror:0.450237	val-merror:0.493213
# [56]	train-merror:0.450213	val-merror:0.492081
# [57]	train-merror:0.450411	val-merror:0.492081
# [58]	train-merror:0.450287	val-merror:0.492081
# [59]	train-merror:0.450287	val-merror:0.489819
# [60]	train-merror:0.450089	val-merror:0.489819
# [61]	train-merror:0.449792	val-merror:0.492081
# [62]	train-merror:0.449817	val-merror:0.49095
# [63]	train-merror:0.450064	val-merror:0.49095
# [64]	train-merror:0.449495	val-merror:0.49095
# [65]	train-merror:0.449347	val-merror:0.49095
# [66]	train-merror:0.449322	val-merror:0.49095
# [67]	train-merror:0.449075	val-merror:0.492081
# [68]	train-merror:0.449026	val-merror:0.492081
# [69]	train-merror:0.449075	val-merror:0.489819
# [70]	train-merror:0.448655	val-merror:0.488688
# [71]	train-merror:0.448556	val-merror:0.489819
# [72]	train-merror:0.448605	val-merror:0.492081
# [73]	train-merror:0.44816	val-merror:0.493213
# [74]	train-merror:0.448036	val-merror:0.493213
# [75]	train-merror:0.448259	val-merror:0.493213
# [76]	train-merror:0.44816	val-merror:0.493213
# [77]	train-merror:0.448185	val-merror:0.494344
# [78]	train-merror:0.448234	val-merror:0.494344
# [79]	train-merror:0.448259	val-merror:0.494344
# [80]	train-merror:0.448185	val-merror:0.494344
# [81]	train-merror:0.44816	val-merror:0.494344
# [82]	train-merror:0.447913	val-merror:0.492081
# [83]	train-merror:0.447789	val-merror:0.492081
# [84]	train-merror:0.447888	val-merror:0.49095
# [85]	train-merror:0.447863	val-merror:0.49095
# [86]	train-merror:0.447764	val-merror:0.49095
# [87]	train-merror:0.447838	val-merror:0.492081
# [88]	train-merror:0.447418	val-merror:0.49095
# [89]	train-merror:0.446898	val-merror:0.492081
# [90]	train-merror:0.447047	val-merror:0.492081
# [91]	train-merror:0.446948	val-merror:0.492081
# [92]	train-merror:0.447022	val-merror:0.492081
# [93]	train-merror:0.446923	val-merror:0.492081
# [94]	train-merror:0.446577	val-merror:0.49095
# [95]	train-merror:0.446676	val-merror:0.493213
# [96]	train-merror:0.446379	val-merror:0.49095
# [97]	train-merror:0.446429	val-merror:0.489819
# [98]	train-merror:0.446404	val-merror:0.492081
# [99]	train-merror:0.44633	val-merror:0.492081
# [100]	train-merror:0.446033	val-merror:0.493213
# [101]	train-merror:0.445959	val-merror:0.494344
# [102]	train-merror:0.445983	val-merror:0.493213
# [103]	train-merror:0.445934	val-merror:0.494344
# [104]	train-merror:0.446231	val-merror:0.492081
# [105]	train-merror:0.446033	val-merror:0.49095
# [106]	train-merror:0.446132	val-merror:0.49095
# [107]	train-merror:0.445983	val-merror:0.49095
# [108]	train-merror:0.446058	val-merror:0.492081
# [109]	train-merror:0.44581	val-merror:0.492081
# [110]	train-merror:0.445761	val-merror:0.493213
# [111]	train-merror:0.445662	val-merror:0.493213
# [112]	train-merror:0.445687	val-merror:0.493213
# [113]	train-merror:0.445662	val-merror:0.49095
# [114]	train-merror:0.445711	val-merror:0.49095
# [115]	train-merror:0.445786	val-merror:0.49095
# [116]	train-merror:0.445711	val-merror:0.49095
# [117]	train-merror:0.445489	val-merror:0.49095
# [118]	train-merror:0.445192	val-merror:0.49095
# [119]	train-merror:0.445266	val-merror:0.49095
# [120]	train-merror:0.444895	val-merror:0.49095
# [121]	train-merror:0.444796	val-merror:0.489819
# [122]	train-merror:0.444673	val-merror:0.489819
# [123]	train-merror:0.444648	val-merror:0.489819
# [124]	train-merror:0.444499	val-merror:0.489819
# [125]	train-merror:0.444524	val-merror:0.489819
# [126]	train-merror:0.444326	val-merror:0.489819
# [127]	train-merror:0.444351	val-merror:0.489819
# [128]	train-merror:0.4444	val-merror:0.489819
# [129]	train-merror:0.444499	val-merror:0.49095
# [130]	train-merror:0.444425	val-merror:0.49095
# [131]	train-merror:0.444351	val-merror:0.49095
# [132]	train-merror:0.444104	val-merror:0.492081
# [133]	train-merror:0.44398	val-merror:0.492081
# [134]	train-merror:0.444128	val-merror:0.493213
# [135]	train-merror:0.443955	val-merror:0.494344
# [136]	train-merror:0.444005	val-merror:0.495475
# [137]	train-merror:0.444029	val-merror:0.492081
# [138]	train-merror:0.443757	val-merror:0.492081
# [139]	train-merror:0.443757	val-merror:0.492081
# [140]	train-merror:0.443609	val-merror:0.492081
# [141]	train-merror:0.443609	val-merror:0.492081
# [142]	train-merror:0.443634	val-merror:0.492081
# [143]	train-merror:0.443807	val-merror:0.489819
# [144]	train-merror:0.44356	val-merror:0.494344
# [145]	train-merror:0.443535	val-merror:0.492081
# [146]	train-merror:0.443485	val-merror:0.49095
# [147]	train-merror:0.443189	val-merror:0.49095
# [148]	train-merror:0.44304	val-merror:0.49095
# [149]	train-merror:0.443139	val-merror:0.489819
# [150]	train-merror:0.443164	val-merror:0.49095
# [151]	train-merror:0.442966	val-merror:0.492081
# [152]	train-merror:0.44304	val-merror:0.493213
# [153]	train-merror:0.443065	val-merror:0.493213
# [154]	train-merror:0.442966	val-merror:0.492081
# [155]	train-merror:0.442966	val-merror:0.49095
# [156]	train-merror:0.442768	val-merror:0.49095
# [157]	train-merror:0.442719	val-merror:0.492081
# [158]	train-merror:0.442719	val-merror:0.492081
# [159]	train-merror:0.442521	val-merror:0.492081
# [160]	train-merror:0.442323	val-merror:0.492081
# [161]	train-merror:0.442001	val-merror:0.492081
# [162]	train-merror:0.441977	val-merror:0.49095
# [163]	train-merror:0.441853	val-merror:0.49095
# [164]	train-merror:0.442051	val-merror:0.492081
# [165]	train-merror:0.441878	val-merror:0.492081
# [166]	train-merror:0.441927	val-merror:0.492081
# [167]	train-merror:0.441606	val-merror:0.489819
# [168]	train-merror:0.44168	val-merror:0.492081
# [169]	train-merror:0.44168	val-merror:0.489819
# [170]	train-merror:0.441729	val-merror:0.49095
# [171]	train-merror:0.441507	val-merror:0.49095
# [172]	train-merror:0.441531	val-merror:0.492081
# [173]	train-merror:0.441433	val-merror:0.49095
# [174]	train-merror:0.441507	val-merror:0.489819
# [175]	train-merror:0.441581	val-merror:0.489819
# [176]	train-merror:0.441383	val-merror:0.488688
# [177]	train-merror:0.440839	val-merror:0.489819
# [178]	train-merror:0.44074	val-merror:0.489819
# [179]	train-merror:0.440493	val-merror:0.488688
# [180]	train-merror:0.440369	val-merror:0.489819
# [181]	train-merror:0.44027	val-merror:0.49095
# [182]	train-merror:0.440146	val-merror:0.49095
# [183]	train-merror:0.44027	val-merror:0.488688
# [184]	train-merror:0.440023	val-merror:0.49095
# [185]	train-merror:0.439899	val-merror:0.49095
# [186]	train-merror:0.4398	val-merror:0.49095
# [187]	train-merror:0.439874	val-merror:0.49095
# [188]	train-merror:0.440072	val-merror:0.49095
# [189]	train-merror:0.439924	val-merror:0.489819
# [190]	train-merror:0.439775	val-merror:0.49095
# [191]	train-merror:0.4398	val-merror:0.49095
# [192]	train-merror:0.4398	val-merror:0.49095
# [193]	train-merror:0.439676	val-merror:0.49095
# [194]	train-merror:0.439701	val-merror:0.488688
# [195]	train-merror:0.439578	val-merror:0.489819
# [196]	train-merror:0.439528	val-merror:0.489819
# [197]	train-merror:0.439256	val-merror:0.489819
# [198]	train-merror:0.439404	val-merror:0.489819
# [199]	train-merror:0.439404	val-merror:0.49095
# [200]	train-merror:0.439404	val-merror:0.49095
# [201]	train-merror:0.439157	val-merror:0.49095
# [202]	train-merror:0.439009	val-merror:0.492081
# [203]	train-merror:0.43886	val-merror:0.494344
# [204]	train-merror:0.438761	val-merror:0.493213
# [205]	train-merror:0.438786	val-merror:0.493213
# [206]	train-merror:0.438712	val-merror:0.493213
# [207]	train-merror:0.438539	val-merror:0.492081
# [208]	train-merror:0.43844	val-merror:0.493213
# [209]	train-merror:0.438242	val-merror:0.493213
# [210]	train-merror:0.438094	val-merror:0.494344
# [211]	train-merror:0.437945	val-merror:0.494344
# [212]	train-merror:0.437871	val-merror:0.494344
# [213]	train-merror:0.437747	val-merror:0.493213
# [214]	train-merror:0.437624	val-merror:0.493213
# [215]	train-merror:0.437673	val-merror:0.493213
# [216]	train-merror:0.437822	val-merror:0.494344
# [217]	train-merror:0.437772	val-merror:0.493213
# [218]	train-merror:0.437475	val-merror:0.493213
# [219]	train-merror:0.437599	val-merror:0.493213
# [220]	train-merror:0.437525	val-merror:0.493213
# [221]	train-merror:0.437154	val-merror:0.493213
# [222]	train-merror:0.437228	val-merror:0.492081
# [223]	train-merror:0.437055	val-merror:0.493213
# [224]	train-merror:0.436684	val-merror:0.493213
# [225]	train-merror:0.436709	val-merror:0.493213
# [226]	train-merror:0.436486	val-merror:0.493213
# [227]	train-merror:0.436659	val-merror:0.492081
# [228]	train-merror:0.436461	val-merror:0.492081
# [229]	train-merror:0.436362	val-merror:0.492081
# [230]	train-merror:0.436362	val-merror:0.493213
# [231]	train-merror:0.436486	val-merror:0.49095
# [232]	train-merror:0.436511	val-merror:0.49095
# [233]	train-merror:0.436412	val-merror:0.492081
# [234]	train-merror:0.436239	val-merror:0.492081
# [235]	train-merror:0.436115	val-merror:0.492081
# [236]	train-merror:0.43614	val-merror:0.492081
# [237]	train-merror:0.435991	val-merror:0.492081
# [238]	train-merror:0.435967	val-merror:0.489819
# [239]	train-merror:0.435694	val-merror:0.492081
# [240]	train-merror:0.435571	val-merror:0.492081
# [241]	train-merror:0.435818	val-merror:0.492081
# [242]	train-merror:0.435571	val-merror:0.492081
# [243]	train-merror:0.435373	val-merror:0.492081
# [244]	train-merror:0.435348	val-merror:0.492081
# [245]	train-merror:0.435348	val-merror:0.492081
# [246]	train-merror:0.435422	val-merror:0.492081
# [247]	train-merror:0.43515	val-merror:0.492081
# [248]	train-merror:0.435126	val-merror:0.49095
# [249]	train-merror:0.435101	val-merror:0.49095
# [250]	train-merror:0.434878	val-merror:0.49095
# [251]	train-merror:0.434854	val-merror:0.49095
# [252]	train-merror:0.434755	val-merror:0.49095
# [253]	train-merror:0.434532	val-merror:0.49095
# [254]	train-merror:0.434359	val-merror:0.49095
# [255]	train-merror:0.434334	val-merror:0.49095
# [256]	train-merror:0.434161	val-merror:0.49095
# [257]	train-merror:0.434136	val-merror:0.492081
# [258]	train-merror:0.43384	val-merror:0.493213
# [259]	train-merror:0.433765	val-merror:0.493213
# [260]	train-merror:0.433617	val-merror:0.492081
# [261]	train-merror:0.433617	val-merror:0.492081
# [262]	train-merror:0.433469	val-merror:0.493213
# [263]	train-merror:0.433271	val-merror:0.493213
# [264]	train-merror:0.43332	val-merror:0.493213
# [265]	train-merror:0.43337	val-merror:0.493213
# [266]	train-merror:0.433394	val-merror:0.493213
# [267]	train-merror:0.433122	val-merror:0.493213
# [268]	train-merror:0.433098	val-merror:0.494344
# [269]	train-merror:0.433246	val-merror:0.494344
# [270]	train-merror:0.433147	val-merror:0.494344
# [271]	train-merror:0.432999	val-merror:0.493213
# [272]	train-merror:0.432776	val-merror:0.493213
# [273]	train-merror:0.432751	val-merror:0.494344
# [274]	train-merror:0.432553	val-merror:0.493213
# [275]	train-merror:0.432405	val-merror:0.492081
# [276]	train-merror:0.432356	val-merror:0.493213
# [277]	train-merror:0.432356	val-merror:0.494344
# [278]	train-merror:0.432232	val-merror:0.494344
# [279]	train-merror:0.432158	val-merror:0.494344
# [280]	train-merror:0.432207	val-merror:0.494344
# [281]	train-merror:0.432182	val-merror:0.494344
# [282]	train-merror:0.432133	val-merror:0.495475
# [283]	train-merror:0.432133	val-merror:0.495475
# [284]	train-merror:0.431935	val-merror:0.495475
# [285]	train-merror:0.431713	val-merror:0.495475
# [286]	train-merror:0.431638	val-merror:0.495475
# [287]	train-merror:0.431539	val-merror:0.495475
# [288]	train-merror:0.431465	val-merror:0.495475
# [289]	train-merror:0.431292	val-merror:0.493213
# [290]	train-merror:0.431045	val-merror:0.495475
# [291]	train-merror:0.431094	val-merror:0.495475
# [292]	train-merror:0.431045	val-merror:0.495475
# [293]	train-merror:0.430896	val-merror:0.495475
# [294]	train-merror:0.430674	val-merror:0.494344
# [295]	train-merror:0.430674	val-merror:0.494344
# [296]	train-merror:0.430649	val-merror:0.493213
# [297]	train-merror:0.430476	val-merror:0.493213
# [298]	train-merror:0.430229	val-merror:0.493213
# [299]	train-merror:0.430031	val-merror:0.493213
# [300]	train-merror:0.430055	val-merror:0.493213
# [301]	train-merror:0.429882	val-merror:0.493213
# [302]	train-merror:0.43008	val-merror:0.493213
# [303]	train-merror:0.430006	val-merror:0.493213
# [304]	train-merror:0.429684	val-merror:0.493213
# [305]	train-merror:0.429487	val-merror:0.493213
# [306]	train-merror:0.429462	val-merror:0.493213
# [307]	train-merror:0.429338	val-merror:0.492081
# [308]	train-merror:0.429289	val-merror:0.492081
# [309]	train-merror:0.429116	val-merror:0.492081
# [310]	train-merror:0.428942	val-merror:0.49095
# [311]	train-merror:0.428794	val-merror:0.49095
# [312]	train-merror:0.428621	val-merror:0.492081
# [313]	train-merror:0.428522	val-merror:0.492081
# [314]	train-merror:0.428374	val-merror:0.492081
# Stopping. Best iteration:
# [14]	train-merror:0.451672	val-merror:0.483032
#
# 14

# %%
pred_probs = model.predict(xgtest, ntree_limit=model.best_iteration)
pred_probs
# Out:
# array([[0.33936977, 0.32758775, 0.33304247],
#        [0.33418375, 0.33119747, 0.3346188 ],
#        [0.3138591 , 0.32415015, 0.36199075],
#        ...,
#        [0.31571126, 0.31986183, 0.36442688],
#        [0.31429586, 0.3236578 , 0.36204633],
#        [0.3512218 , 0.3286724 , 0.3201058 ]], dtype=float32)

# %%
def get_result(items):
    if items[0] <= items[1] and items[0] <= items[2]:
        return [1,2]
    elif items[1] <= items[0] and items[1] <= items[2]:
        return [0,2]
    elif items[2] <= items[0] and items[2] <= items[1]:
        return [0,1]
    
def cal_win_rate(fix_results, pred_probs):
    results = []
    for i in range(len(pred_probs)):
        items = pred_probs[i]
        probs = get_result(items)

        if fix_results[i] in probs:
            results.append(1)
        else:
            results.append(0)
    return results

# %%
fix_results = test_dataset['fix_result'].values
results = cal_win_rate(fix_results, pred_probs)
np.array(results).sum() / len(results)
# Out:
# 0.7611026033690659
